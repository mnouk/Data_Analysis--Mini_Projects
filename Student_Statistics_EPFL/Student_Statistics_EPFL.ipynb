# %%
from bs4 import BeautifulSoup as bs
import requests
from IPython.display import HTML
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ## LEXICOGRAPHY : "##" Multiline Comment "#" Single line comment "###" Code that has been commented.

# %% [markdown]
#
#                      PART I - Generating the fixed params for the HTTP GET request

# %%
## Firstly we need to download the data using Requests and BeautifulSoup.
## The basic URL used is http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247

# query_form is the form used to download the spreadsheets

query_form = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247')

# %%
# Creating a parse tree rooted at the BeautifulSoup object using a html parser.
soup = bs(query_form.text, "html.parser")

# %%
## Firstly, let us look at the form used to download the spreadsheets
HTML(query_form.text)
# Out:
# <html><head><META http-equiv="Content-Type" content="text/html; charset=iso-8859-1"><div></div><title></title><script type="text/javascript" src="GEDPUBLICREPORTS.txt?ww_x_path=Gestac.Base.Palette_js&amp;ww_c_langue=fr"></script><link rel="stylesheet" type="text/css" href="GEDPUBLICREPORTS.css?ww_x_path=Gestac.Moniteur.Style"><link rel="stylesheet" type="text/css" href="GEDPUBLICREPORTS.css?ww_x_path=Gestac.Moniteur.StyleNavigator"></head><body bgcolor="#ffffff" marginheight="0" marginwidth="5" link="#666666" vlink="#666666" alink="#666666"><div class="filtres"><form method="GET" name="f" action="!GEDPUBLICREPORTS.filter"><input type="hidden" name="ww_b_list" value="1"><input type="hidden" name="ww_i_reportmodel" value="133685247"><input type="hidden" name="ww_c_langue" value=""><h1 id="titre">Liste des étudiants inscrits par semestre</h1><table border="0" id="format"><tr><th>Format:</th></tr><tr><td><input type="radio" name="ww_i_reportModelXsl" value="133685270" checked>html</td></tr><tr><td><input type="radio" name="ww_i_reportModelXsl" value="133685271">xls</td></tr></table><h1></h1><table border="0" id="filtre"><tr><th>Unité académique</th><td><input type="hidden" name="zz_x_UNITE_ACAD" value=""><select name="ww_x_UNITE_ACAD" onchange="document.f.zz_x_UNITE_ACAD.value=document.f.ww_x_UNITE_ACAD.options[document.f.ww_x_UNITE_ACAD.selectedIndex].text"><option value="null"></option><option value="942293">Architecture</option><option value="246696">Chimie et génie chimique</option><option value="943282">Cours de mathématiques spéciales</option><option value="637841336">EME (EPFL Middle East)</option><option value="942623">Génie civil</option><option value="944263">Génie mécanique</option><option value="943936">Génie électrique et électronique </option><option value="2054839157">Humanités digitales</option><option value="249847">Informatique</option><option value="120623110">Ingénierie financière</option><option value="946882">Management de la technologie</option><option value="944590">Mathématiques</option><option value="945244">Microtechnique</option><option value="945571">Physique</option><option value="944917">Science et génie des matériaux</option><option value="942953">Sciences et ingénierie de l'environnement</option><option value="945901">Sciences et technologies du vivant</option><option value="1574548993">Section FCUE</option><option value="946228">Systèmes de communication</option></select></td></tr><tr><th>Période académique</th><td><input type="hidden" name="zz_x_PERIODE_ACAD" value=""><select name="ww_x_PERIODE_ACAD" onchange="document.f.zz_x_PERIODE_ACAD.value=document.f.ww_x_PERIODE_ACAD.options[document.f.ww_x_PERIODE_ACAD.selectedIndex].text"><option value="null"></option><option value="355925344">2016-2017</option><option value="213638028">2015-2016</option><option value="213637922">2014-2015</option><option value="213637754">2013-2014</option><option value="123456101">2012-2013</option><option value="123455150">2011-2012</option><option value="39486325">2010-2011</option><option value="978195">2009-2010</option><option value="978187">2008-2009</option><option value="978181">2007-2008</option></select></td></tr><tr><th>Période pédagogique</th><td><input type="hidden" name="zz_x_PERIODE_PEDAGO" value=""><select name="ww_x_PERIODE_PEDAGO" onchange="document.f.zz_x_PERIODE_PEDAGO.value=document.f.ww_x_PERIODE_PEDAGO.options[document.f.ww_x_PERIODE_PEDAGO.selectedIndex].text"><option value="null"></option><option value="249108">Bachelor semestre 1</option><option value="249114">Bachelor semestre 2</option><option value="942155">Bachelor semestre 3</option><option value="942163">Bachelor semestre 4</option><option value="942120">Bachelor semestre 5</option><option value="2226768">Bachelor semestre 5b</option><option value="942175">Bachelor semestre 6</option><option value="2226785">Bachelor semestre 6b</option><option value="2230106">Master semestre 1</option><option value="942192">Master semestre 2</option><opti ...
#    function loadReport(x) {
#     var querysup='';
#     writeRunning(top.principal);
#     for (i=0; document.f.elements.length > i; i++){
#      if (document.f.elements[i].checked){
#       querysup=querysup+'&'+document.f.elements[i].name+'='+document.f.elements[i].value;
#      }
#      if (document.f.elements[i].type=='select-one') {
#       querysup=querysup+'&'+document.f.elements[i].name+'='+document.f.elements[i].options[document.f.elements[i].selectedIndex].value;
#      }
#      if (document.f.elements[i].type=='text'){
#       querysup=querysup+'&'+document.f.elements[i].name+'='+document.f.elements[i].value;
#      }
#     }
#     parent.principal.location = "!GEDPUBLICREPORTS.bhtml?"+x+"&ww_i_reportModel=133685247"+querysup;
#     if (navigator.userAgent.toUpperCase().indexOf('SAFARI') != -1) {
#      document.location.reload();
#     }
#    }
#   </script><h1></h1><table border="0"></table></div></body></html>
# <!-- OpenXml:0.01s  agent ctrl:0.00s  xml:0.49s  xsl clob before parse:0.01s  xsl extr&stylesheet:0.00s  xsl clob before parse:0.00s  xsl after parsing:0.00s  xsl ctrl data:0.00s  transform 2:0.04s  xsl process:0.00s  -->

# %%
## It always helps to see the html source to decide what to do next.

###print(soup.prettify())

# %%
## We would like to automate the request, to do so we first look at how many inputs are required:

inputs = soup.find_all('input')
print ("There are", len(inputs) ,"inputs in all : \n")

for inp in inputs:
    print(inp['name'],"===>",inp['value'])
print("\n")

## Out of these inputs, there are some fields to select.

selections = soup.find_all('select')
print ("There are", len(selections) ,"selections in all : \n")

for sel in selections:
    print(sel["name"])
# Out:
# There are 10 inputs in all :
#
# ww_b_list ===> 1
# ww_i_reportmodel ===> 133685247
# ww_c_langue ===>
# ww_i_reportModelXsl ===> 133685270
# ww_i_reportModelXsl ===> 133685271
# zz_x_UNITE_ACAD ===>
# zz_x_PERIODE_ACAD ===>
# zz_x_PERIODE_PEDAGO ===>
# zz_x_HIVERETE ===>
# dummy ===> ok
#
#
# There are 4 selections in all :
#
# ww_x_UNITE_ACAD
# ww_x_PERIODE_ACAD
# ww_x_PERIODE_PEDAGO
# ww_x_HIVERETE

# %%
## We start creating the filters to go with our HTTP request
## The ww_x_GPS is set to -1 to get "Tous" c.f. slack. 

payload_head = {'ww_x_GPS' : '-1'}

## Observe that the name ww_i_reportModelXls appears twice and only one value interstes us.
#  We mean to download xls files so we LET the value for ww_i_reportModelXsl be overwritten!!

for inp in inputs[:5]:
    payload_head[inp['name']] = inp['value']

# %%
## Each selection has different options to choose from; We print them out here
soup.find_all('option')
# Out:
# [<option value="null"></option>,
#  <option value="942293">Architecture</option>,
#  <option value="246696">Chimie et génie chimique</option>,
#  <option value="943282">Cours de mathématiques spéciales</option>,
#  <option value="637841336">EME (EPFL Middle East)</option>,
#  <option value="942623">Génie civil</option>,
#  <option value="944263">Génie mécanique</option>,
#  <option value="943936">Génie électrique et électronique </option>,
#  <option value="2054839157">Humanités digitales</option>,
#  <option value="249847">Informatique</option>,
#  <option value="120623110">Ingénierie financière</option>,
#  <option value="946882">Management de la technologie</option>,
#  <option value="944590">Mathématiques</option>,
#  <option value="945244">Microtechnique</option>,
#  <option value="945571">Physique</option>,
#  <option value="944917">Science et génie des matériaux</option>,
#  <option value="942953">Sciences et ingénierie de l'environnement</option>,
#  <option value="945901">Sciences et technologies du vivant</option>,
#  <option value="1574548993">Section FCUE</option>,
#  <option value="946228">Systèmes de communication</option>,
#  <option value="null"></option>,
#  <option value="355925344">2016-2017</option>,
#  <option value="213638028">2015-2016</option>,
#  <option value="213637922">2014-2015</option>,
#  <option value="213637754">2013-2014</option>,
#  <option value="123456101">2012-2013</option>,
#  <option value="123455150">2011-2012</option>,
#  <option value="39486325">2010-2011</option>,
#  <option value="978195">2009-2010</option>,
#  <option value="978187">2008-2009</option>,
#  <option value="978181">2007-2008</option>,
#  <option value="null"></option>,
#  <option value="249108">Bachelor semestre 1</option>,
#  <option value="249114">Bachelor semestre 2</option>,
#  <option value="942155">Bachelor semestre 3</option>,
#  <option value="942163">Bachelor semestre 4</option>,
#  <option value="942120">Bachelor semestre 5</option>,
#  <option value="2226768">Bachelor semestre 5b</option>,
#  <option value="942175">Bachelor semestre 6</option>,
#  <option value="2226785">Bachelor semestre 6b</option>,
#  <option value="2230106">Master semestre 1</option>,
#  <option value="942192">Master semestre 2</option>,
#  <option value="2230128">Master semestre 3</option>,
#  <option value="2230140">Master semestre 4</option>,
#  <option value="2335667">Mineur semestre 1</option>,
#  <option value="2335676">Mineur semestre 2</option>,
#  <option value="2063602308">Mise à niveau</option>,
#  <option value="249127">Projet Master automne</option>,
#  <option value="3781783">Projet Master printemps</option>,
#  <option value="953159">Semestre automne</option>,
#  <option value="2754553">Semestre printemps</option>,
#  <option value="953137">Stage automne 3ème année</option>,
#  <option value="2226616">Stage automne 4ème année</option>,
#  <option value="983606">Stage printemps 3ème année</option>,
#  <option value="2226626">Stage printemps 4ème année</option>,
#  <option value="2227132">Stage printemps master</option>,
#  <option value="null"></option>,
#  <option value="2936286">Semestre d'automne</option>,
#  <option value="2936295">Semestre de printemps</option>]

# %%
## We now concentrate on the section Informatique and add it to payload
info = soup.find('option', text = "Informatique")
payload_head[info.parent['name']] = info['value']

payload_head
# Out:
# {'ww_b_list': '1',
#  'ww_c_langue': '',
#  'ww_i_reportModelXsl': '133685271',
#  'ww_i_reportmodel': '133685247',
#  'ww_x_GPS': '-1',
#  'ww_x_UNITE_ACAD': '249847'}

# %% [markdown]
#                 END OF PART 1, WE HAVE THE BASIC ELEMENTS OF THE GET REQUEST READY.

# %%
## We are now capable of generating a request for any xls file.
## For this we make a few arrays to iterate over like year, semester etc.

years = ["2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]


payload_tail = {}

# %%
## Now, the fun part, we iterate for each year and get all the data for odd(autumn) semesters first
## and then the even(spring) semesters. Append the text vales of returned HTTP response to teh files
## array and their respective URLs to the urls array(Just in case).
## At each iteration, we upload the payload_head to send the appropriate HTTP GET request.

files = []

for y in years:
    year = soup.find('option', text = y)
    payload_tail[year.parent['name']] = year['value']

    one = soup.find('option', text = "Bachelor semestre 1")
    payload_tail[one.parent['name']] = one['value']
    payload_head.update(payload_tail)
    r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.XLS?ww_i_reportModel=133685247', params = payload_head ) 
    files.append(r.text)
        
    six = soup.find('option', text = "Bachelor semestre 6")
    payload_tail[six.parent['name']] = six['value']
    payload_head.update(payload_tail)
    r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.XLS?ww_i_reportModel=133685247', params = payload_head ) 
    files.append(r.text)
        
print("Downloaded", len(files) , "Files for Bachelors Sem 1 and Sem 6 from 2007 to 2016")
# Out:
# Downloaded 20 Files for Bachelors Sem 1 and Sem 6 from 2007 to 2016

# %%
## Proof that the above code is not voodoo. :)
HTML(files[1])
# Out:
# <html><head><META http-equiv="Content-Type" content="text/html; charset=iso-8859-1"><title></title></head><body bgcolor="#ffffff" marginheight="0" marginwidth="5" link="#666666" vlink="#666666" alink="#666666"><script>
#   function mailList(x) {
#    var vtop = (screen.height-200)/2;
#    var vleft=(screen.width-600)/2;
#    var w=open("", "emaillist", "Scrollbars=1,resizable=1,width=600,height=200,top="+vtop+",left="+vleft);
#    w.document.write(x);
#    w.document.close();
#    w.focus();
#   }
#  </script><table><tr><th colspan="10">
#     Ces listes d'étudiants ne seront définitives qu'ŕ la mi-aoűt une fois la commission d'admission bachelor et la conférence d'examen passées afin de s'assurer que tous les étudiants nouvellement admis ŕ l'EPFL y figurent et que les étudiants en situation d'échec définitif soient rayés de ces listes
#    </th></tr><tr><th colspan="12"><font color="black">Informatique, 2007-2008, Bachelor semestre 6</font>
# &nbsp;(38 ét.)
#     </th></tr><tr><th>Civilité</th><th>Nom Prénom</th><th>Orientation Bachelor</th><th>Orientation Master</th><th>Spécialisation</th><th>Filičre opt.</th><th>Mineur</th><th>Statut</th><th>Type Echange</th><th>Ecole Echange</th><th>No Sciper</th></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Barras&nbsp;Florian</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>170220</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Beuret&nbsp;Thibaut</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>166701</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Biollay&nbsp;Jean Isaac Jamal Pachacutec</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>161279</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Blatter&nbsp;Jérémy</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>166344</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Boksanyi&nbsp;Michael</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>161634</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Bolkensteyn&nbsp;Dinesh</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>170451</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">
# 23     NaN  Présent           NaN            NaN     178786 NaN NaN
# 24     NaN  Présent           NaN            NaN     179567 NaN NaN
# 25     NaN  Présent           NaN            NaN     176282 NaN NaN
# 26     NaN  Présent           NaN            NaN     178656 NaN NaN
# 27     NaN  Présent           NaN            NaN     181445 NaN NaN
# 28     NaN  Présent           NaN            NaN     178718 NaN NaN
# 29     NaN  Présent           NaN            NaN     175466 NaN NaN
# 30     NaN  Présent           NaN            NaN     173882 NaN NaN
# 31     NaN  Présent           NaN            NaN     181612 NaN NaN
# 32     NaN  Présent           NaN            NaN     181232 NaN NaN
# 33     NaN  Présent           NaN            NaN     178706 NaN NaN
# 34     NaN  Présent           NaN            NaN     180284 NaN NaN
# 35     NaN  Présent           NaN            NaN     181121 NaN NaN
# 36     NaN  Présent           NaN            NaN     170509 NaN NaN
# 37     NaN    Congé           NaN            NaN     175379 NaN NaN
# 38     NaN  Présent           NaN            NaN     180570 NaN NaN
# 39     NaN  Présent           NaN            NaN     178604 NaN NaN
# 40     NaN  Présent           NaN            NaN     175190 NaN NaN
# 41     NaN  Présent           NaN            NaN     178660 NaN NaN
# 42     NaN  Présent           NaN            NaN     181248 NaN NaN
# 43     NaN  Présent           NaN            NaN     179163 NaN NaN
# 44     NaN  Présent           NaN            NaN     181181 NaN NaN
# 45     NaN  Présent           NaN            NaN     181244 NaN NaN
# 46     NaN  Présent           NaN            NaN     175685 NaN NaN
# 47     NaN  Présent           NaN            NaN     169731 NaN NaN
# 48     NaN  Présent           NaN            NaN     175001 NaN NaN
# 49     NaN  Présent           NaN            NaN     181424 NaN NaN

# %%
## Creating a useable dataframe for the above html-based datadframe. 

def prepare_dataframe(f):
    file = pd.read_html(f)[0]
    period = file.loc[1, 0].split(',')
    file.drop([0,1], inplace = True)
    file.drop([2,3,4,5,6,7,8,9,11,12], axis = 1, inplace = True)
    file.columns = file.loc[2]
    file.columns.name = 0
    file["Sem " + period[2].split(' ')[3]] = int(period[1].split('-')[0])
    file.drop(2, inplace = True)
    file = file.set_index('No Sciper')
    return file

# %%
## Dreating an array with all the cleaned dataframes/ files
dfiles = []
for f in files:
    dfiles.append(prepare_dataframe(f))

# %%
## Concatenating all dataframes into one (indices not unique)
cfile = pd.concat(dfiles)
cfile.sort()
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   app.launch_new_instance()
#            Civilité                                         Nom Prénom  \
# No Sciper
# 147008     Monsieur                                        Good Xavier
# 147008     Monsieur                                        Good Xavier
# 153762     Monsieur                                       Conus Johann
# 159516     Monsieur                                        Raja Yanick
# 159998       Madame                                        Jesse Julia
# 161091       Madame                                   Grivet Ekaterina
# 161127     Monsieur                                      Sahy François
# 161212     Monsieur                                     Tamesna Rachid
# 161220     Monsieur                                      Tourino Pablo
# 161220     Monsieur                                      Tourino Pablo
# 161279     Monsieur                Biollay Jean Isaac Jamal Pachacutec
# 161279     Monsieur                Biollay Jean Isaac Jamal Pachacutec
# 161634     Monsieur                                   Boksanyi Michael
# 161814     Monsieur                                    Candemir Mehmet
# 161814     Monsieur                                    Candemir Mehmet
# ...           ...     ...
# 274740     2016.0     NaN
# 274746     2016.0     NaN
# 274748     2016.0     NaN
# 274751     2016.0     NaN
# 274839     2016.0     NaN
# 274900     2016.0     NaN
# 274902     2016.0     NaN
# 274918     2016.0     NaN
# 274944     2016.0     NaN
# 274957     2016.0     NaN
# 274960     2016.0     NaN
# 274999     2016.0     NaN
# 275001     2016.0     NaN
# 275071     2016.0     NaN
# 275102     2016.0     NaN
# 275105     2016.0     NaN
# 275116     2016.0     NaN
# 275142     2016.0     NaN
# 275159     2016.0     NaN
# 275199     2016.0     NaN
# 275273     2016.0     NaN
# 275313     2016.0     NaN
# 275383     2016.0     NaN
# 275553     2016.0     NaN
# 275608     2016.0     NaN
# 276016     2016.0     NaN
# 276323     2016.0     NaN
# 276507     2016.0     NaN
# 276937     2016.0     NaN
# 277113     2016.0     NaN
#
# [2384 rows x 4 columns]

# %%
## Collecting non null values for sem 6 and making a new data frame
## Dropping the second time someone does the Bachelo semester 1
## Keeping the last time someone does the Bachelor semester 6
sem6 = pd.DataFrame(cfile['Sem 6'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'last')
sem1 = pd.DataFrame(cfile['Sem 1'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'first')
gender = pd.DataFrame(cfile['Civilité']).reset_index()

# %%
final = pd.merge(sem1, sem6, on = 'No Sciper', how = 'inner')
final = pd.merge(final, gender, on ='No Sciper', how = 'inner')
final = final.set_index('No Sciper')

## Assumption : the question reads time between bachelor semster 1 and 6 so we consider only these two. 
## Time is the difference between the first time a student is in bachelor semester 1 to the last time 
## he/she is in semester 6

final["Time"] = (final["Sem 6"] - final["Sem 1"] + 0.5)*12

print( "population mean =", [final["Time"].mean()],"months")

## Printing the dataframe with the years and gender indexed on Sciper
final
# Out:
# population mean = [38.08641975308642] months
#             Sem 1   Sem 6  Civilité  Time
# No Sciper
# 169569     2007.0  2009.0  Monsieur  30.0
# 169569     2007.0  2009.0  Monsieur  30.0
# 174905     2007.0  2011.0  Monsieur  54.0
# 174905     2007.0  2011.0  Monsieur  54.0
# 174905     2007.0  2011.0  Monsieur  54.0
# 179406     2007.0  2010.0  Monsieur  42.0
# 179406     2007.0  2010.0  Monsieur  42.0
# 179406     2007.0  2010.0  Monsieur  42.0
# 179428     2007.0  2010.0  Monsieur  42.0
# 179428     2007.0  2010.0  Monsieur  42.0
# 179428     2007.0  2010.0  Monsieur  42.0
# 179449     2007.0  2009.0  Monsieur  30.0
# 179449     2007.0  2009.0  Monsieur  30.0
# 178553     2007.0  2009.0  Monsieur  30.0
# 178553     2007.0  2009.0  Monsieur  30.0
# 179426     2007.0  2010.0  Monsieur  42.0
# 179426     2007.0  2010.0  Monsieur  42.0
# 179426     2007.0  2010.0  Monsieur  42.0
# 178271     2007.0  2009.0  Monsieur  30.0
# 178271     2007.0  2009.0  Monsieur  30.0
# 180731     2007.0  2009.0  Monsieur  30.0
# 180731     2007.0  2009.0  Monsieur  30.0
# 171619     2007.0  2009.0  Monsieur  30.0
# 171619     2007.0  2009.0  Monsieur  30.0
# 179157     2007.0  2010.0  Monsieur  42.0
# 179157     2007.0  2010.0  Monsieur  42.0
# 179157     2007.0  2010.0  Monsieur  42.0
# 178711     2007.0  2010.0  Monsieur  42.0
# 178711     2007.0  2010.0  Monsieur  42.0
# 178711     2007.0  2010.0  Monsieur  42.0
# ...           ...     ...       ...   ...
# 250300     2014.0  2016.0  Monsieur  30.0
# 250300     2014.0  2016.0  Monsieur  30.0
# 249954     2014.0  2016.0  Monsieur  30.0
# 249954     2014.0  2016.0  Monsieur  30.0
# 249996     2014.0  2016.0  Monsieur  30.0
# 249996     2014.0  2016.0  Monsieur  30.0
# 239489     2014.0  2016.0    Madame  30.0
# 239489     2014.0  2016.0    Madame  30.0
# 246663     2014.0  2016.0  Monsieur  30.0
# 246663     2014.0  2016.0  Monsieur  30.0
# 245511     2014.0  2016.0  Monsieur  30.0
# 245511     2014.0  2016.0  Monsieur  30.0
# 250703     2014.0  2016.0  Monsieur  30.0
# 250703     2014.0  2016.0  Monsieur  30.0
# 245512     2014.0  2016.0  Monsieur  30.0
# 245512     2014.0  2016.0  Monsieur  30.0
# 247855     2014.0  2016.0  Monsieur  30.0
# 247855     2014.0  2016.0  Monsieur  30.0
# 245782     2014.0  2016.0  Monsieur  30.0
# 245782     2014.0  2016.0  Monsieur  30.0
# 247233     2014.0  2016.0  Monsieur  30.0
# 247233     2014.0  2016.0  Monsieur  30.0
# 250362     2014.0  2016.0  Monsieur  30.0
# 250362     2014.0  2016.0  Monsieur  30.0
# 247680     2014.0  2016.0  Monsieur  30.0
# 247680     2014.0  2016.0  Monsieur  30.0
# 246532     2014.0  2016.0  Monsieur  30.0
# 246532     2014.0  2016.0  Monsieur  30.0
# 247891     2014.0  2016.0  Monsieur  30.0
# 247891     2014.0  2016.0  Monsieur  30.0
#
# [972 rows x 4 columns]

# %%
## Grouping men and women into the grouped groupby object
grouped = final.groupby('Civilité')

## Means per gender group
group_counts = grouped.mean()
group_counts.drop(['Sem 1', 'Sem 6'] , axis = 1)
# Out:
#                Time
# Civilité
# Madame    35.194030
# Monsieur  38.300552

# %%
## Statistical test: the Two-sample T-Test
## With the data we have we can reject the hypothesis that men and women take the same amount of time.

# %%
hommes = final.loc[final.Civilité == 'Monsieur']["Time"].values 
femmes = final.loc[final.Civilité == 'Madame']["Time"].values

stats.ttest_ind(a= hommes, b= femmes, equal_var=False)
# Out:
# Ttest_indResult(statistic=3.2489769011682865, pvalue=0.0016476806088724187)

# %% [markdown]
# ### QUESTION TWO

# %%
##Preparing master dataframe similarly to the bachelor

master_files = []
semesters = [" 1" , " 2", " 3"]
for y in years:
    year = soup.find('option', text = y)
    payload_tail[year.parent['name']] = year['value']
    for sem in semesters:
        one = soup.find('option', text = "Master semestre" + sem)
        payload_tail[one.parent['name']] = one['value']
        payload_head.update(payload_tail)
        r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.XLS?ww_i_reportModel=133685247', params = payload_head ) 
        master_files.append(r.text)

# %%
HTML(master_files[1])
# Out:
# <html><head><META http-equiv="Content-Type" content="text/html; charset=iso-8859-1"><title></title></head><body bgcolor="#ffffff" marginheight="0" marginwidth="5" link="#666666" vlink="#666666" alink="#666666"><script>
#   function mailList(x) {
#    var vtop = (screen.height-200)/2;
#    var vleft=(screen.width-600)/2;
#    var w=open("", "emaillist", "Scrollbars=1,resizable=1,width=600,height=200,top="+vtop+",left="+vleft);
#    w.document.write(x);
#    w.document.close();
#    w.focus();
#   }
#  </script><table><tr><th colspan="10">
#     Ces listes d'étudiants ne seront définitives qu'ŕ la mi-aoűt une fois la commission d'admission bachelor et la conférence d'examen passées afin de s'assurer que tous les étudiants nouvellement admis ŕ l'EPFL y figurent et que les étudiants en situation d'échec définitif soient rayés de ces listes
#    </th></tr><tr><th colspan="12"><font color="black">Informatique, 2007-2008, Master semestre 2</font>
# &nbsp;(87 ét.)
#     </th></tr><tr><th>Civilité</th><th>Nom Prénom</th><th>Orientation Bachelor</th><th>Orientation Master</th><th>Spécialisation</th><th>Filičre opt.</th><th>Mineur</th><th>Statut</th><th>Type Echange</th><th>Ecole Echange</th><th>No Sciper</th></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Aeberhard&nbsp;François-Xavier</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>153066</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Madame</td><td style="white-space:nowrap">Agarwal&nbsp;Megha</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>180027</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Anagnostaras&nbsp;David</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Mineur en Management, technologie et entrepreneuriat</td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>152232</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Auroux&nbsp;Damien</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Internet computing</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>177395</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Awalebo&nbsp;Joseph</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>161970</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Balet&nbsp;Ken</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>166258</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap">Barazzutti&nbsp;Raphaël Pierre</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td style="white-space:nowrap">Présent</td><td style="white-space:nowrap"></td><td style="white-space:nowrap"></td><td>173600</td><td style="white-space:nowrap"><a href="mailto:"></a></td><td style="white-space:nowrap"></td></tr><tr><td style="white-space:nowrap">Monsieur</td><td style="white-space:nowrap"> ...

# %%
def prepare_master_dataframe(f):
    file = pd.read_html(f)[0]
    period = file.loc[1, 0].split(',')
    file.drop([0,1], inplace = True)
    file.drop([2,3,5,7,8,9,11,12], axis = 1, inplace = True)
    file.columns = file.loc[2]
    file.columns.name = 0
    file["Sem " + period[2].split(' ')[3]] = int(period[1].split('-')[0])
    file.drop(2, inplace = True)
    file = file.set_index('No Sciper')
    return file

# %%
dfiles_master = []
for f in master_files:
    dfiles_master.append(prepare_master_dataframe(f))

# %%
dfiles_master[1]
# Out:
# 0          Civilité                 Nom Prénom  \
# No Sciper
# 153066     Monsieur  Aeberhard François-Xavier
# 180027       Madame              Agarwal Megha
# 152232     Monsieur         Anagnostaras David
# 177395     Monsieur              Auroux Damien
# 161970     Monsieur             Awalebo Joseph
# 166258     Monsieur                  Balet Ken
# 173600     Monsieur  Barazzutti Raphaël Pierre
# 178879     Monsieur           Bayramoglu Ersoy
# 160213     Monsieur         Bécholey Alexandre
# 154573       Madame         Benabdallah Zeineb
# 160492     Monsieur                Bettex Marc
# 172687     Monsieur               Billaud Joël
# 153742     Monsieur              Bozzo Vincent
# 179802     Monsieur            Brightwell Mark
# 162618       Madame              Bucher Cécile
# 180072     Monsieur             Campora Simone
# 153324     Monsieur            Cantale Nicolas
# 146330     Monsieur           Cardinaux Damien
# 160148       Madame            Casati Nathalie
# 160225     Monsieur          Cassata Alexandre
# 153746     Monsieur               Cassina Ilya
# 160718     Monsieur          Copponnex Hadrien
# 166001     Monsieur            Di Maďo Vincent
# 172500       Madame  Diatchka Kremena Sotirova
# 154643     Monsieur                Dumont Loďc
# 166772     Monsieur          Dupasquier Benoît
# 167168     Monsieur             Fardel Ludovic
# 166805     Monsieur        Fleury Marc-Olivier
# 154080     Monsieur        Fomene Tierry Alain
# 169702     Monsieur              Galdos Andoni
# ...             ...                        ...
# 161024       Madame            Meinen Jennifer
# 167133     Monsieur            Moulin François
# 161344     Monsieur                 Muńoz Iván
# 179878     Monsieur        Muriel Hugo Marcelo
# 160893     Monsieur     Ngallemo Hever Patrick
# 129326     Monsieur             Ni Zhong Zhong
# 180269     Monsieur             Ninkovic Marko
# 180160     Monsieur               Pakzad Pooya
# 177636     Monsieur             Pilchen Jerome
# 166262     Monsieur          Plancherel Pascal
# 179716     Monsieur          Pollet Christophe
# 177393     Monsieur             Rabie Stéphane
# 177476     Monsieur            Ragnerstam Erik
# 166079       Madame             Rochat Aurélia
# 166263     Monsieur             Roux Alexandre
# 161138     Monsieur           Sauthier Ludovic
# 160991     Monsieur             Schintgen Joël
# 155018     Monsieur               Signori Jean
# 167387     Monsieur          Spiess Christophe
# 174036     Monsieur          Stachowiak Robert
# 154706     Monsieur             Suter François
# 167447     Monsieur         Taggiasco Matthieu
# 178057       Madame                Tomar Anmol
# 155093     Monsieur         Wafellman Jonathan
# 155097     Monsieur                    Wei Zhe
# 155124     Monsieur             Yersin Antoine
# 169839     Monsieur            Zalakain Ilazki
# 172221     Monsieur                   Zheng Da
# 129093     Monsieur                 Zhou Maoan
# 166264     Monsieur            Zufferey Damien
#
# 0                          Spécialisation  \
# No Sciper
# 153066                                NaN
# 180027                                NaN
# 152232                                NaN
# 177395                 Internet computing
# 161970                                NaN
# 166258                                NaN
# 173600                                NaN
# 178879                                NaN
# 160213                                NaN
# 154573                                NaN
# 160492                                NaN
# 172687                                NaN
# 153742     Signals, Images and Interfaces
# 179802                                NaN
# 162618                                NaN
# 180072                 Internet computing
# 153324                                NaN
# 146330                                NaN
# 160148                                NaN
# 160225                                NaN
# 153746                                NaN
# 160718            Foundations of Software
# 166001                                NaN
# 172500                       Biocomputing
# 154643                                NaN
# 166772                                NaN
# 167168                                NaN
# 166805                                NaN
# 154080                                NaN
# 169702                                NaN
# ...                                   ...
# 161024                                NaN
# 167133                                NaN
# 161344          Computer Engineering - SP
# 179878                 Internet computing
# 160893                                NaN
# 129326                                NaN
# 180269                                NaN
# 180160                 Internet computing
# 177636                                NaN
# 166262                                NaN
# 179716                 Internet computing
# 177393                                NaN
# 177476                                NaN
# 166079                                NaN
# 166263            Foundations of Software
# 161138                                NaN
# 160991                 Internet computing
# 155018                                NaN
# 167387                                NaN
# 174036     Signals, Images and Interfaces
# 154706                                NaN
# 167447                                NaN
# 178057                                NaN
# 155093                 Internet computing
# 155097                                NaN
# 155124                                NaN
# 169839                                NaN
# 172221                 Internet computing
# 129093                                NaN
# 166264            Foundations of Software
#
# 0                                                     Mineur  Sem 2
# No Sciper
# 153066                                                   NaN   2007
# 180027                                                   NaN   2007
# 152232     Mineur en Management, technologie et entrepren...   2007
# 177395                                                   NaN   2007
# 161970                                                   NaN   2007
# 166258                                                   NaN   2007
# 173600                                                   NaN   2007
# 178879                                                   NaN   2007
# 160213                                                   NaN   2007
# 154573                                                   NaN   2007
# 160492                                                   NaN   2007
# 172687                                                   NaN   2007
# 153742                                                   NaN   2007
# 179802                                                   NaN   2007
# 162618                                                   NaN   2007
# 180072                                                   NaN   2007
# 153324                                                   NaN   2007
# 146330                                                   NaN   2007
# 160148                                                   NaN   2007
# 160225                                                   NaN   2007
# 153746                                                   NaN   2007
# 160718                                                   NaN   2007
# 166001                                                   NaN   2007
# 172500                                                   NaN   2007
# 154643                                                   NaN   2007
# 166772                                                   NaN   2007
# 167168                                                   NaN   2007
# 166805                                                   NaN   2007
# 154080                                                   NaN   2007
# 169702                                                   NaN   2007
# ...                                                      ...    ...
# 161024                                                   NaN   2007
# 167133                                                   NaN   2007
# 161344                                                   NaN   2007
# 179878                                                   NaN   2007
# 160893                                                   NaN   2007
# 129326                                                   NaN   2007
# 180269                                                   NaN   2007
# 180160                                                   NaN   2007
# 177636                                                   NaN   2007
# 166262                                                   NaN   2007
# 179716                                                   NaN   2007
# 177393                                                   NaN   2007
# 177476                                                   NaN   2007
# 166079                                                   NaN   2007
# 166263                                                   NaN   2007
# 161138                                                   NaN   2007
# 160991                                                   NaN   2007
# 155018                                                   NaN   2007
# 167387                                                   NaN   2007
# 174036                                                   NaN   2007
# 154706                                                   NaN   2007
# 167447                                                   NaN   2007
# 178057                                                   NaN   2007
# 155093                                                   NaN   2007
# 155097                                                   NaN   2007
# 155124                                                   NaN   2007
# 169839                                                   NaN   2007
# 172221                                                   NaN   2007
# 129093                                                   NaN   2007
# 166264                                                   NaN   2007
#
# [87 rows x 5 columns]

# %%
cfile_master = pd.concat(dfiles_master)
cfile_master.sort()
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   from ipykernel import kernelapp as app
#            Civilité Mineur                                         Nom Prénom  \
# No Sciper
# 128911     Monsieur    NaN                                     Gulati Asheesh
# 128911     Monsieur    NaN                                     Gulati Asheesh
# 129093     Monsieur    NaN                                         Zhou Maoan
# 129093     Monsieur    NaN                                         Zhou Maoan
# 129326     Monsieur    NaN                                     Ni Zhong Zhong
# 129326     Monsieur    NaN                                     Ni Zhong Zhong
# 138088     Monsieur    NaN                            Droz-dit-Busset Arnault
# 145546     Monsieur    NaN                               Clivaz Jean-Philippe
# 145957     Monsieur    NaN                                      Hügli Michael
# 146330     Monsieur    NaN                                   Cardinaux Damien
# 146330     Monsieur    NaN                                   Cardinaux Damien
# 146330     Monsieur    NaN                                   Cardinaux Damien
# 146441       Madame    NaN                                   Henriot Laetitia
# 146742     Monsieur    NaN                                       Marx Clément
# 146742     Monsieur    NaN                                       Marx Clément
# 146742     Monsieur    NaN                                       Marx Clément
# 180161                        Garessus Samuel  2007.0    NaN     NaN
# 172264                            Garg Nikhil  2007.0    NaN     NaN
# 160578                         Gascon Grégory  2007.0    NaN     NaN
# 161357                      Gfeller Sebastian  2007.0    NaN     NaN
# ...                                       ...     ...    ...     ...
# 217393      Plancherel Nicolas Bernard Lucien     NaN    NaN  2016.0
# 251558                        Popovic Radmila     NaN    NaN  2016.0
# 244270                      Racine Jason Rémy     NaN    NaN  2016.0
# 228358                         Raemy Baptiste     NaN    NaN  2016.0
# 225274                     Raho Moritz Fabian     NaN    NaN  2016.0
# 184366                         Regamey Samuel     NaN    NaN  2016.0
# 223287                Reich Nicolas Alexandre     NaN    NaN  2016.0
# 205095            Renucci Allan Vincent Roger     NaN    NaN  2016.0
# 260806      Rouault Sébastien Louis Alexandre     NaN    NaN  2016.0
# 216690                            Roulin Andy     NaN    NaN  2016.0
# 217489                Salathé Joanna Béatrice     NaN    NaN  2016.0
# 256553                  Sarigiannis Dimitrios     NaN    NaN  2016.0
# 186020                      Schaeffer Yannick     NaN    NaN  2016.0
# 217500                         Séchaud Gaétan     NaN    NaN  2016.0
# 204222                Séguy Louis Marie James     NaN    NaN  2016.0
# 224304                    Semple Alexis Nabil     NaN    NaN  2016.0
# 217056                        Sottas Baptiste     NaN    NaN  2016.0
# 256612                 Sympetheros Alexandros     NaN    NaN  2016.0
# 223529     Tafani-Dereeper Christophe Clément     NaN    NaN  2016.0
# 227590                     Theytaz Joël Régis     NaN    NaN  2016.0
# 224639                  Torche Jérôme William     NaN    NaN  2016.0
# 223825                   Vassor Martin Thomas     NaN    NaN  2016.0
# 225096                         Vessaz Yannick     NaN    NaN  2016.0
# 224295       Veuthey Alexandre Bernard Robert     NaN    NaN  2016.0
# 196683                   Vostriakov Alexander     NaN    NaN  2016.0
# 254478                          Wang Junxiong     NaN    NaN  2016.0
# 240268                  Yüzügüler Ahmet Caner     NaN    NaN  2016.0
# 261146                         Zakhour George     NaN    NaN  2016.0
# 256870                              Zhou Lisa     NaN    NaN  2016.0
# 170946                     Zimmermann Florian     NaN    NaN  2016.0
#
#                            Spécialisation
# No Sciper
# 153066                                NaN
# 180027                                NaN
# 152232                                NaN
# 177395                                NaN
# 161970                                NaN
# 166258                                NaN
# 173600                                NaN
# 178879                                NaN
# 154573                                NaN
# 160492                                NaN
# 172687                                NaN
# 179802                                NaN
# 162618                                NaN
# 180072                 Internet computing
# 146330                                NaN
# 160148                                NaN
# 160225                                NaN
# 153746                                NaN
# 160718                                NaN
# 138088                                NaN
# 154643                                NaN
# 166772                                NaN
# 167168                                NaN
# 166805                                NaN
# 154080                                NaN
# 169702                                NaN
# 180161                                NaN
# 172264                                NaN
# 160578                                NaN
# 161357                                NaN
# ...                                   ...
# 217393                                NaN
# 251558                                NaN
# 244270                                NaN
# 228358                 Internet computing
# 225274                   Software Systems
# 184366                                NaN
# 223287                 Internet computing
# 205095                                NaN
# 260806                   Software Systems
# 216690          Computer Engineering - SP
# 217489                                NaN
# 256553                     Data Analytics
# 186020                   Software Systems
# 217500                                NaN
# 204222                                NaN
# 224304                 Internet computing
# 217056                                NaN
# 256612                                NaN
# 223529                                NaN
# 227590          Information Security - SP
# 224639                 Internet computing
# 223825          Computer Engineering - SP
# 225096                 Internet computing
# 224295                                NaN
# 196683                                NaN
# 254478                                NaN
# 240268                                NaN
# 261146                                NaN
# 256870                                NaN
# 170946     Signals, Images and Interfaces
#
# [2716 rows x 7 columns]

# %%
msem2 = pd.DataFrame(cfile_master['Sem 2'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'last')
msem1 = pd.DataFrame(cfile_master['Sem 1'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'first')
msem3 = pd.DataFrame(cfile_master['Sem 3'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'last')

mgender = pd.DataFrame(cfile_master['Civilité']).reset_index().drop_duplicates('No Sciper', keep = 'first')
mineur = pd.DataFrame(cfile_master['Mineur'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'first')
spec = pd.DataFrame(cfile_master['Spécialisation'].dropna()).reset_index().drop_duplicates('No Sciper', keep = 'first')

# %%
final_master_1 = pd.merge(msem1, msem2, on = 'No Sciper', how = 'inner')

final_master_1 = pd.merge(final_master_1, mgender, on ='No Sciper', how = 'inner')
final_master_1 = final_master_1.set_index('No Sciper')

## Assumption : the question reads time between master semster 1 and 2 so we consider only these two. 
## Time is the difference between the first time a student is in master semester 1 to the last time 
## in master semster 2 but people can start in master sem 2, so we take the absolute value. 

final_master_1["Time"] = abs((final_master_1["Sem 2"] - final_master_1["Sem 1"] + 0.5)*12)

print( "population mean =", [final_master_1["Time"].mean()],"months")

## Printing the dataframe with the years and gender indexed on Sciper
final_master_1
# Out:
# population mean = [9.785340314136125] months
#             Sem 1   Sem 2  Civilité  Time
# No Sciper
# 153066     2007.0  2009.0  Monsieur  30.0
# 180027     2007.0  2007.0    Madame   6.0
# 152232     2007.0  2007.0  Monsieur   6.0
# 177395     2007.0  2007.0  Monsieur   6.0
# 161970     2007.0  2007.0  Monsieur   6.0
# 166258     2007.0  2007.0  Monsieur   6.0
# 173600     2007.0  2007.0  Monsieur   6.0
# 178879     2007.0  2007.0  Monsieur   6.0
# 154573     2007.0  2008.0    Madame  18.0
# 160492     2007.0  2007.0  Monsieur   6.0
# 172687     2007.0  2007.0  Monsieur   6.0
# 179802     2007.0  2007.0  Monsieur   6.0
# 162618     2007.0  2007.0    Madame   6.0
# 180072     2007.0  2007.0  Monsieur   6.0
# 146330     2007.0  2007.0  Monsieur   6.0
# 160148     2007.0  2007.0    Madame   6.0
# 160225     2007.0  2007.0  Monsieur   6.0
# 153746     2007.0  2007.0  Monsieur   6.0
# 160718     2007.0  2007.0  Monsieur   6.0
# 154643     2007.0  2007.0  Monsieur   6.0
# 166772     2007.0  2007.0  Monsieur   6.0
# 167168     2007.0  2008.0  Monsieur  18.0
# 166805     2007.0  2007.0  Monsieur   6.0
# 154080     2007.0  2008.0  Monsieur  18.0
# 169702     2007.0  2007.0  Monsieur   6.0
# 172264     2007.0  2007.0  Monsieur   6.0
# 160578     2007.0  2007.0  Monsieur   6.0
# 161357     2007.0  2007.0  Monsieur   6.0
# 177399     2007.0  2007.0  Monsieur   6.0
# 166921     2007.0  2007.0  Monsieur   6.0
# ...           ...     ...       ...   ...
# 217500     2015.0  2015.0  Monsieur   6.0
# 204222     2015.0  2015.0  Monsieur   6.0
# 224304     2015.0  2015.0  Monsieur   6.0
# 217056     2015.0  2015.0  Monsieur   6.0
# 256612     2015.0  2015.0  Monsieur   6.0
# 193832     2015.0  2015.0  Monsieur   6.0
# 223529     2015.0  2015.0  Monsieur   6.0
# 256846     2015.0  2015.0  Monsieur   6.0
# 225316     2015.0  2015.0  Monsieur   6.0
# 227590     2015.0  2015.0  Monsieur   6.0
# 224639     2015.0  2015.0  Monsieur   6.0
# 214573     2015.0  2015.0  Monsieur   6.0
# 223825     2015.0  2015.0  Monsieur   6.0
# 225096     2015.0  2015.0  Monsieur   6.0
# 224295     2015.0  2015.0  Monsieur   6.0
# 221063     2015.0  2015.0  Monsieur   6.0
# 254478     2015.0  2015.0  Monsieur   6.0
# 240268     2015.0  2015.0  Monsieur   6.0
# 261146     2015.0  2015.0  Monsieur   6.0
# 256870     2015.0  2015.0    Madame   6.0
# 227209     2016.0  2015.0  Monsieur   6.0
# 202973     2016.0  2015.0  Monsieur   6.0
# 247875     2016.0  2015.0  Monsieur   6.0
# 224847     2016.0  2015.0  Monsieur   6.0
# 204869     2016.0  2015.0  Monsieur   6.0
# 225688     2016.0  2015.0  Monsieur   6.0
# 225749     2016.0  2015.0  Monsieur   6.0
# 218357     2016.0  2015.0  Monsieur   6.0
# 208359     2016.0  2015.0  Monsieur   6.0
# 209450     2016.0  2015.0  Monsieur   6.0
#
# [764 rows x 4 columns]

# %%
### People doing a Minor

final_master_2 = pd.merge(msem1, msem3, on = 'No Sciper', how = 'inner')
final_master_2 = pd.merge(final_master_2, mgender, on ='No Sciper', how = 'inner')
final_master_2 = pd.merge(final_master_2, mineur, on ='No Sciper', how = 'inner')
final_master_2 = final_master_2.set_index('No Sciper')

## Assumption : the question reads time between master semster 1 and 3 for those people with minors 
## so we consider only these three. 
## Time is the difference between the first time a student is in master semester 1 to the last time 
## in master semster 2 but people can start in master sem 2, so we take the absolute value. 

final_master_2["Time"] = abs((final_master_2["Sem 3"] - final_master_2["Sem 1"] + 0.5)*12)

mean_2 = final_master_2["Time"].mean()
print( "population mean =", [final_master_2["Time"].mean()],"months")

## Printing the dataframe with the years and gender indexed on Sciper
final_master_2
# Out:
# population mean = [20.72] months
#             Sem 1   Sem 3  Civilité  \
# No Sciper
# 152232     2007.0  2008.0  Monsieur
# 170451     2008.0  2010.0  Monsieur
# 166751     2008.0  2009.0  Monsieur
# 167045     2008.0  2010.0  Monsieur
# 170220     2009.0  2011.0  Monsieur
# 170225     2009.0  2010.0  Monsieur
# 191589     2009.0  2010.0    Madame
# 176564     2009.0  2010.0  Monsieur
# 171073     2009.0  2010.0  Monsieur
# 193545     2009.0  2010.0    Madame
# 203301     Mineur en Management, technologie et entrepren...  18.0
# 179988     Mineur en Management, technologie et entrepren...  42.0
# 185042                                Mineur en Biocomputing  30.0
# 196602     Mineur en Management, technologie et entrepren...  18.0
# 201113                            Information security minor  18.0
# 193160     Mineur en Management, technologie et entrepren...  18.0
# 184772                       Area and Cultural Studies minor  18.0
# 213553     Mineur en Management, technologie et entrepren...  18.0
# 211684                               Mineur en Mathématiques  30.0
# 194971                            Information security minor  18.0
# 214731     Mineur en Management, technologie et entrepren...  18.0
# 214614     Mineur en Management, technologie et entrepren...  18.0
# ...                                                      ...   ...
# 201017                      Mineur en Technologies spatiales  18.0
# 206436                            Information security minor  18.0
# 233543                                Mineur en Biocomputing  18.0
# 186872     Mineur en Management, technologie et entrepren...  30.0
# 186193                       Area and Cultural Studies minor  18.0
# 205784                       Mineur en Ingénierie financičre  18.0
# 192304     Mineur en Management, technologie et entrepren...  18.0
# 238215                                Mineur en Biocomputing  18.0
# 232957                       Mineur en Ingénierie financičre  18.0
# 203457     Mineur en Management, technologie et entrepren...  30.0
# 245475                       Mineur en Ingénierie financičre  18.0
# 213664     Mineur en Management, technologie et entrepren...  18.0
# 203945     Mineur en Management, technologie et entrepren...  18.0
# 244136     Mineur en Management, technologie et entrepren...  18.0
# 201905                            Information security minor  18.0
# 238078                            Information security minor  18.0
# 227848                            Information security minor  18.0
# 217453                            Information security minor  30.0
# 214101                       Mineur en Ingénierie financičre  18.0
# 196683             Mineur en Neurosciences computationnelles  30.0
# 248358     Mineur en Management, technologie et entrepren...  18.0
# 225483     Mineur en Management, technologie et entrepren...  18.0
# 213027     Mineur en Management, technologie et entrepren...  18.0
# 216451                       Mineur en Ingénierie financičre  18.0
# 256231                              Mineur en Microtechnique  18.0
# 192219     Mineur en Management, technologie et entrepren...  18.0
# 251723             Mineur en Neurosciences computationnelles  18.0
# 255203                       Mineur en Ingénierie financičre  18.0
# 217489     Mineur en Management, technologie et entrepren...  18.0
# 256612     Mineur en Management, technologie et entrepren...  18.0
#
# [75 rows x 5 columns]

# %%
### People doing a specialisation

final_master_3 = pd.merge(msem1, msem3, on = 'No Sciper', how = 'inner')
final_master_3 = pd.merge(final_master_3, mgender, on ='No Sciper', how = 'inner')
final_master_3 = pd.merge(final_master_3, spec, on ='No Sciper', how = 'inner')
final_master_3 = final_master_3.set_index('No Sciper')

## Assumption : the question reads time between master semster 1 and 3 for those people with minors 
## so we consider only these three. 
## Time is the difference between the first time a student is in master semester 1 to the last time 
## in master semster 2 but people can start in master sem 2, so we take the absolute value. 

final_master_3["Time"] = abs((final_master_3["Sem 3"] - final_master_3["Sem 1"] + 0.5)*12)

mean_3 = final_master_3["Time"].mean()
print( "population mean =", [final_master_3["Time"].mean()],"months")

## Printing the dataframe with the years and gender indexed on Sciper
final_master_3
# Out:
# population mean = [20.829694323144103] months
#             Sem 1   Sem 3  Civilité                  Spécialisation  Time
# No Sciper
# 153066     2007.0  2009.0  Monsieur              Internet computing  30.0
# 177395     2007.0  2008.0  Monsieur              Internet computing  18.0
# 166258     2007.0  2008.0  Monsieur              Internet computing  18.0
# 154573     2007.0  2009.0    Madame                    Biocomputing  30.0
# 180072     2007.0  2008.0  Monsieur              Internet computing  18.0
# 160718     2007.0  2008.0  Monsieur         Foundations of Software  18.0
#
# 227590     2015.0  2016.0  Monsieur       Information Security - SP  18.0
# 224639     2015.0  2016.0  Monsieur              Internet computing  18.0
# 223825     2015.0  2016.0  Monsieur       Computer Engineering - SP  18.0
# 225096     2015.0  2016.0  Monsieur              Internet computing  18.0
#
# [229 rows x 5 columns]

# %%
## MEAN STAY AT EPFL MASTER
## The average time spent for finishing master 1 to master 3, WE IGNORE MASTER PROJECT AS IT IS NOT ALWAYS AT EPFL
## And the data is too sparse to be useful.

## The mean is simply the mean of means as mean is a linear operation 

mean_stay = numpy.mean([mean_2 , mean_3])
print("The mean stay for STUDIES in EPFL is " ,mean_stay)
# Out:
# The mean stay for STUDIES in EPFL is  20.7748471616

# %%
## MEAN PER SPECIALISATION
## Grouping specialisations into the grouped groupby object
grouped_spec = final_master_3.groupby('Spécialisation')

## Means per gender group
group_spec_counts = grouped_spec.mean()
group_spec_counts.drop(['Sem 1', 'Sem 3'] , axis = 1)
# Out:
#                                      Time
# Spécialisation
# Biocomputing                    24.000000
# Computer Engineering - SP       19.894737
# Computer Science Theory         18.000000
# Data Analytics                  18.000000
# Foundations of Software         21.103448
# Information Security - SP       18.000000
# Internet Information Systems    18.000000
# Internet computing              20.682353
# Service science                 20.400000
# Signals, Images and Interfaces  23.793103
# Software Systems                18.000000

# %%
## COMPARING SAMPLE MEANS WITH THE POPULATION MEAN 
biocomputing = final_master_3.loc[final_master_3.Spécialisation == 'Biocomputing']["Time"].values 
print("Biocomputing", stats.ttest_1samp(a = biocomputing , popmean = mean_stay ))

computer_engg = final_master_3.loc[final_master_3.Spécialisation == 'Computer Engineering - SP']["Time"].values 
print("Computer Engineering", stats.ttest_1samp(a = computer_engg , popmean = mean_stay ))

computer_theory = final_master_3.loc[final_master_3.Spécialisation == 'Computer Science Theory']["Time"].values
print("Computer Science Theory", stats.ttest_1samp(a = computer_theory , popmean = mean_stay ))

data_analytics = final_master_3.loc[final_master_3.Spécialisation == 'Data Analytics']["Time"].values
print("Data Analytics", stats.ttest_1samp(a = data_analytics  , popmean = mean_stay ))
# Out:
# Biocomputing Ttest_1sampResult(statistic=0.93102142972203095, pvalue=0.42051903711803867)
# Computer Engineering Ttest_1sampResult(statistic=-0.85334589168706076, pvalue=0.40468064365519851)
# Computer Science Theory Ttest_1sampResult(statistic=nan, pvalue=nan)
# Data Analytics Ttest_1sampResult(statistic=-inf, pvalue=0.0)
# //anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)

# %% [markdown]
# ### QUESTION BONUS

# %%
final_master_4 = pd.merge(msem1, msem3, on = 'No Sciper', how = 'inner')
final_master_4 = pd.merge(final_master_4, mgender, on ='No Sciper', how = 'inner')
final_master_4 = final_master_4.set_index('No Sciper')

## MEAN PER GENDER
## Grouping specialisations into the grouped groupby object
grouped_gen = final_master_4.groupby('Civilité')

final_master_4["Time"] = abs((final_master_4["Sem 3"] - final_master_4["Sem 1"] + 0.5)*12)

## Means per gender group
group_gen_counts = grouped_gen.mean()
group_gen_counts.drop(['Sem 1', 'Sem 3'] , axis = 1)
# Out:
#                Time
# Civilité
# Madame    19.783784
# Monsieur  19.693252
