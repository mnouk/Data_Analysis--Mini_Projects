# %%
import pandas as pd
import nltk
from nltk import *
import nltk.sentiment
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# ## WORD CLOUDS

# %%
emails_df = pd.read_csv('Emails.csv', index_col='Id')

# %%
emails_df.shape
# Out:
# (7945, 21)

# %% [markdown]
# ### Cleaning

# %%
emails_df.columns
# Out:
# Index(['DocNumber', 'MetadataSubject', 'MetadataTo', 'MetadataFrom',
#        'SenderPersonId', 'MetadataDateSent', 'MetadataDateReleased',
#        'MetadataPdfLink', 'MetadataCaseNumber', 'MetadataDocumentClass',
#        'ExtractedSubject', 'ExtractedTo', 'ExtractedFrom', 'ExtractedCc',
#        'ExtractedDateSent', 'ExtractedCaseNumber', 'ExtractedDocNumber',
#        'ExtractedDateReleased', 'ExtractedReleaseInPartOrFull',
#        'ExtractedBodyText', 'RawText'],
#       dtype='object')

# %%
emails_df.ExtractedBodyText.isnull().value_counts()
# Out:
# False    6742
# True     1203
# Name: ExtractedBodyText, dtype: int64

# %%
emails_df.RawText.isnull().value_counts()
# Out:
# False    7945
# Name: RawText, dtype: int64

# %% [markdown]
# #### ExtractedBodyText is not very dependable as shown here:

# %%
print(emails_df.ExtractedBodyText[1])
# Out:
# nan

# %%
print(emails_df.RawText[1])
# Out:
# UNCLASSIFIED
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739545
# Date: 05/13/2015
# STATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM.
# SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER.
# RELEASE IN FULL
# From: Sullivan, Jacob J <Sullivan11@state.gov>
# Sent: Wednesday, September 12, 2012 10:16 AM
# To:
# Subject: FW: Wow
# From: Brose, Christian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi
# Sent: Wednesday, September 12, 2012 10:09 AM
# To: Sullivan, Jacob J
# Subject: Wow
# What a wonderful, strong and moving statement by your boss. please tell her how much Sen. McCain appreciated it. Me
# too
# UNCLASSIFIED
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739545
# Date: 05/13/2015
# STATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM.
# SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-5CB0045247

# %% [markdown]
# #### Extracting the raw emails manually

# %%
emails_raw =  emails_df.RawText.str.cat(sep = '\n')

# %%
email_lines = emails_raw.splitlines()

# %%
len(email_lines)
# Out:
# 348419

# %%
len(set(email_lines))
# Out:
# 169541

# %%
email_lines = list(set(email_lines))
email_lines
# Out:
# ['',
#  'positive results. The Oslo accords were a real step toward peace, not another',
#  'No — unfortunately —',
#  "Clinton's remarks.",
#  'Sent: Wednesday, January 20, 2010 6:24 AM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05767166 Date: 08/31/2015',
#  'government spokesman, was made after repeated calls by senior U.S. officials for more Arab support to help build',
#  'Sent: Thursday, January 14, 2010 4:18 AM',
#  'trilogy. Linking these three issues thematically, we can explain how and why foreign policy challenges and solutions',
#  'Internet to defend freedom of expression, this kind of repression would be much more difficult. I am not talking about',
#  'just before Mr. Gates issued his warning, the chairman of the Joint Chiefs of Staff, Adm. Mike Mullen, wrote an official',
#  'If there is a caveat to the depiction of the Obama administration as White House-centric, it is in the alliance between',
#  'seems that our best exit strategy would be to take down the top leadership of Al Qaeda in Pakistan, and then gradually',
#  "compensate for the discomfort and stress that Saudi Arabia's religiously sanctioned mores impose on them. Methods of",
#  'welfare, or urbanization had to win credibility with the whales. "But if you wanted to do something there was a mechanism',
#  'Copyright 2009 Dow Jones & Company, Inc. All Rights Reserved',
#  'alternatives to extremist ideology; and developing a strategic communications strategy to',
#  'in aid to Pakistan over the next five years, and when Washington is pressing a reluctant Pakistani military to focus its',
#  'At around the same time, the administration was running into trouble with plans to move to northern Virginia at',
#  'I will now.',
#  'period into two parts: confrontation resulting from both sides being well matched in',
#  'Sent: Sun, Sep 12, 2010 8:43 am',
#  'W: 202.647.7062 I F: 202.647.9140 I 2: DouglasWT©state.gov',
#  'U.S. intervening in politics, but, rather, as a very personal message from someone who cares deeply about Thailand. The',
#  'modem diplomacy and conflict prevention to be',
#  'I believe that taking those steps on an urgent basis, While completing the previously planned and announced increase in',
#  "The committee leadership assignments won't be doled out for at least two to three weeks, our Hill sources report.",
#  'accommodations with the unions. So I listed them as the third choice on these merits. However, a part of me wants to',
#  "The underlying problems, however, haven't changed. Karzai still has little appetite for attacking the corruption",
#  'By Henry A. Kissinger, George P. Shultz, James A. Baker III, Lawrence S. Eagleburger and Colin L. Powell',
#  'H; Shah, Rajiv (AID/A) <',
#  'I have hist sent Wilma euidanre on Goldstone to mint out which takes a strong line. Key points:',
#  'horrible mistake." According to diZerega, Charles supported the school',
#  'proclaiming their commitment to the relationship in speech after speech before pro-Israel groups.',
#  'Grover Norquist, who holds a weekly meeting for conservative leaders in Washington, including representatives from',
#  'also vowed to close the military prison in',
#  "I guess from the schedule, we couldn't change the time of the Singapore mtg to later? I'm sorry we only have 20 minutes",
#  'From: Buhl, Cindy',
#  'Sent: Tuesday, March 29, 201105:36 PM',
#  'are. The talks last night/early morning ended more positively and if that is still the case there may be a decision to push',
#  "4:15 pm Secretary's Office *Official photo in anteroom preceding.",
#  'members to ease restrictions and open up expanded relations with Cuba — hardly the action of a',
#  'Sent: Friday, June 18, 2010 7:33 AM',
#  'Verveer, Melanne S <VerveerMS@state.gov>',
#  'H; jake.sullivar',
#  'compelling story of what we hope to accomplish in terms of civilian effort a.k.a. nation building. The standard needs to',
#  'Sent: Sun Dec 20 17:05:29 2009',
#  'Sent: Monday, December 14, 2009 1:53 PM',
#  'tions have the potential to reduce the',
#  'preferred term. That there was interagency discussion of this, and that going forward, we will join the rest of',
#  'candidate and local community',
#  '1:20 pm DEPART Blair House *En route State Department',
#  "lilt idea of S t.0 ';:;Ei(i.ittCor Leahy to i'lag our concerns about cuts to food security, Pakistan FMF",
#  '-- Finally, there is the defining relationship with India. Are there measures that the Indians could take',
#  'From: Jordan, Brannon',
#  'Thank you for sharing this infor w/ me. I will share it w/ the secretary and president clinton.',
#  'Sent: Thu Oct 14 17:25:48 2010',
#  'Sent: Tue May 11 07:13:32 2010',
#  'whether Muammar Qaddafi remains in power or not, the political division of Libya will give',
#  'From: Fogarty, Daniel J',
#  "Subject Fw: (Reuters) UK's Brown calls London meeting on Yemen on January 28",
#  'Sent: Thursday, December 03, 2009 4:52 PM',
#  'Foreign Policy - we have a tenative list from Michael Fuchs i will email to you - it still needs work. We did not',
#  '• Improve coordination in planning and budgeting across our diplomacy and',
#  'general election before its scheduled date in 2011, dismissing media',
#  'Sent: Wednesday, June 2, 2010 10:14 PM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05769998 Date: 08/31/2015',
#  'the honor of his country after a period of disgrace. On the day that Holbrooke suffered the cataclysmic collapse from',
#  'After the Cuban discussion ended, we toured the HUEH hospital with Drs. Henry and Thimothe followed by a long',
#  'Subject: Questions',
#  'expect and hope for our nominees to move after that.',
#  'Many important postwar accomplishments were conceived and pushed by Germany, sometimes over the opposition of',
#  'depends on AF/PDPA for expertise and advice on understanding, informing, engaging,',
#  "Thank you, we'll make that change.",
#  'will the destruction likely go higher than the final numbers of I believe $8.5 b. for Mitch/George but the cost of',
#  'Direct Financial Implications: moving/remodeling',
#  '"I guess that was prophetic," he said, shaking his head.',
#  '23 (2) The 2006 National Security Strategy of the',
#  'AF:',
#  'To: Koh, Harold Hongju; Merten, Kenneth H; Kennedy, Patrick F',
#  'When President George W. Bush went to Ghana in February 2008, he avoided venues',
#  'This email is unclassified',
#  'one wants to relive the horrible Great Terror of the 1980s after the revolution, when faction-',
#  'Sent: Wednesday, September 23, 2009 11:33 AM',
#  "To: Muscatine, Lissa; 'daniel.baer",
#  'activities in the 1950s and dabbling in the political campaign against Bill',
#  'Appointed on 22nd January 2009, as special envoy for Afghanistan/ Pakistan, Holbrooke was',
#  'vice-president of the company and the C.E.O. of its Chemical Technology Group. A',
#  '(See our December 24, 2011 editorial, \'MIA on the Shores of Tripoli.") Qatar and the United Arab Emirates',
#  'he had to take tough measures against the demonstrators, and protect the interests of the U.S. and',
#  'Let me start some thinking',
#  'From: Sullivan, Jacob1 <SullivanJJ@state.gov>',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05775452 Date: 08/31/2015',
#  'recommend it, these are points from him about what to say. And they asked if you would do today.',
#  'phase"—early in the spring, before Obama',
#  'Iranian politics — the immensely costly subsidies on food and energy. His initial efforts to reduce the amount of',
#  'Outdoors/b/ref=sa_menufan10?ie=UTF8&node=3386071>',
#  'Europeans. Mandelson was eager to Miliband to take the EU post, allowing',
#  '5:25 pm DEPART University of Louisville',
#  'November 29 elections in Honduras. We see transparent, free, and fair',
#  'also, of course, inherited by the present administration. Thus, according to the international Monetary Fund the impact of',
#  'I should point out that Pat Kennedy and the CIO have been great. This has been one of several instances where they',
#  'Evo Morales anunciO hoy que su Gobierno pedira a Naciones Unidas una reunion de emergencia para "repudiar y',
#  'Subject: Follow up',
#  'do no damage.',
#  'for the two big new jobs being created under Lisbon — the European president and a European foreign minister or high',
#  'gives rise to mistrust and skepticism, providing ample opportunities to counteract for those, who oppose the process. We',
#  'RE: 10 Amcits in Haiti',
#  'The argument at the time was that harboring terrorism was the same as launching terrorism and that those who',
#  'From: Whitaker, Kevin M',
#  '"There were anti-gay protesters who became violent and the police used tear gas, which our chargee and other',
#  'Democrats; Alexander and Ben Cardin, of Maryland, have introduced a bill to ban mountaintop-removal coal mining.',
#  'Financial Crisis',
#  'debate over whether to move an omnibus spending bill for fiscal 2011 or',
#  '• Per Tarhouni, the next steps are: 1) find Muammar Qadhafi; 2) issue a statement announcing the end of',
#  'Sent: Tuesday, June 9, 2009 1:12 PM',
#  "author's consent, and must not be retained longer than is necessary for the fulfilment of the purpose for which the information is to be used. All",
#  'Subject: Pfizer case (cvsg)',
#  'productivity; market access; and policy, statistics and advocacy; and managed a team of more than 60',
#  '9:30 am Benjamin Franklin Room, 8th Floor',
#  'that the possible failures and omissions do not supersede the positive and timely work done by the entities undertaking',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05758985 Date: 06/30/2015',
#  'Chinese authorities also have suggested that instability in China is bad for the rest of the world because of adverse effects',
#  'largest cause of death in the',
#  'blasphemy laws. (Indonesia too has stepped back from a move to liberalise its blasphemy regime.)',
#  'He said: "Supposing he (Japanese PM Naoto Kan) decided to do otherwise, then what? Then the Senkaku islands will',
#  ">» about the ideas I'm putting together on sports. I do think there is",
#  'To: Sullivan, Jacobi; Mull, Stephen D',
#  'country, are increasingly replacing popular support with repression. This election seems to have called',
#  'which called for Gore to emphasize more his own passion and initiatives. Then the president said Gore could have a',
#  'To: Tillemann, Tomicah S',
#  'Sent: Tuesday, August 3, 2010 7:05 PM',
#  'favor, although it didn\'t seem like a favor back then," Charles has written. "By',
#  'and capabilities, the civilian response corps and I suspect your QDDR recommendations, on how to imagine a sector by',
#  'Bani Walid approximately 100 miles south of Tripoli, in an area still loyal to the Qaddafi family,',
#  'reflect patronage and favour rather than performance. The post-conflict imperative of achieving',
#  'Subject: Re: Haiti recovery blueprint includes foreign donors',
#  'QUESTION: Yeah, yeah, yeah.',
#  'marginalized civilian agencies such as the U.S. Agency for International Development, preparing for a world in',
#  'president, the conservative',
#  'Yesterday Bernard Avishai, adjunct professor at Hebrew University, author of The Hebrew Republic, and a',
#  'in order to remove their mutual misunderstandings. At present, the U.S. enjoys cordial relations with both',
#  'Hi, Yes; I am at (en route to airport). Thank you!',
#  'whose aid was worth about $485 million in 21309 — from scratch to break what it describes as a corrupt cartel of Somali distributors.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05767385 Date: 07/31/2015',
#  'Sent: Tuesday, April 20, 2010 10:08 AM',
#  'carries a distinct Democratic advantage as a majority-minority district. President Barack Obama',
#  'Russia; the Global Initiative to Combat Nuclear Terrorism, which brings together 75',
#  'Sent: Tue Nov 23 19:28:13 2010',
#  '-lope all is well with you. B Sent from my Verizon Wireless',
#  "with every day, from alcohol to food to cigarettes, a lot of the things that aren't good for our health. But the",
#  'media gave positive coverage to U.S. efforts in Haiti, including Radio Nacional de Angola',
#  'skills, strategies, and tools. To that end, we are broadening the way we conceive of diplomacy as',
#  'To: Abedin, Huma; Sullivan, Jacob 3; S_SpecialAssistants',
#  'and-a-half hours during which she was asked invasive and humiliating personal questions. Despite',
#  '[FOR TOKYO AND SEOUL] The United States remains committed to the',
#  'and he respectfully encouraged her to reinstate the funding as quickly as possible so as to send a clear message to',
#  'but did not lead to success. In addition, postcon-',
#  'Arabs on many levels. In framing the issue this way, Israel and the United States appear to be asking for something well',
#  'Sent: Sat Jan 3022:33:51 2010',
#  'Sent: Tuesday, September 8, 2009 8:26 AM',
#  'Sent: Thursday, May 07, 2009 6:38 AM',
#  'The Likud Party charter flatly rejects the establishment of a Palestinian Arab',
#  'To: <betsyebelind',
#  '17 development outcomes and impacts.',
#  'of several steps we are taking to stop this illicit and deadly trade.',
#  'heads," he added, referring to Ansar Al-Shariah\'s black banner.',
#  "Rec'd all 7.",
#  '68% growth',
#  'Subject: Karl and Zak en route to Islamabad',
#  'CDM:',
#  "straightforward way of doing business that doesn't seek to hide or massage spending figures by tucking extra",
#  'KtLt/Abt IN',
#  'Sent: Thursday, September 3, 2009 8:48 PM',
#  'accomplishment -- what happens to the other 80 percent of the workforce?',
#  "To: Steinberg, James'B",
#  'interview before that call. It is, as Amb Schmierer said, unhelpful.',
#  'Sent: Sunday, October 10, 2010 9:08 AM',
#  'given needs to balance regional representations. Still, we should submit one or two names for consideration. Our',
#  'Our leverage at the negotiating table in Copenhagen will depend directly on our ability to offer a strong',
#  'that the harsh military sanctions have weakened Iran, said the official, there is still no sign that they have',
#  'Sent: Saturday, September 25, 2010 7:52 AM',
#  'construction within settlements might be permitted if confined to the already built-up areas of the settlements.',
#  'The Omanis also dealt with Iranian President Mahmoud Ahmadinejad, saying that negotiators enjoyed good access to',
#  'Members upon the return of their constituents. Each week, we will review our cultural program participant list and send',
#  '<http://capweb.democracyinaction.org/dia/track.jsp?v=2&c=YPiiTJTwUTM1Y7X8EDa9sGmGnHaKXNYs>',
#  'have abandoned support for end-of-life counseling.',
#  'have it all. At a minimum, they and others like them should form the core of a group that meets regularly with Obama on',
#  'it was impossible to see how [Hans] Blix [chief weapons inspector] could bring',
#  'touchdown, because that would have unbelievable consequences, grievous consequences, for the',
#  '[Zionist Organization of',
#  "Ein 11:11:11F.Ifc,9oN,y.'tr.g report in the leading daily",
#  "- Holbrooke called me this morning with a point that hasn't been presented to u. He doesn't think u absolutely have to",
#  '"The wave is there, there is a rebellion in the country, and we have good candidates," Mr. Boehner told his supporters,',
#  'Sent: Tuesday, June 1, 2010 5:05 AM',
#  'Sent: Sat Jan 30 16:49:16 2010',
#  'Subject: Re: John Kerry',
#  'this week. Please let S know. Coming back to DC Thursday.',
#  'have been well documented by international human rights groups, as well as by multiple documentary and',
#  'Israeli peace process, which Mr Obama launched on his second day in office when he appointed George Mitchell as his',
#  'From: obwhoeop <sbwhoeop',
#  'Sent: Sunday, May 30, 2010 12:12 AM',
#  'coordination and share best practices, we will seek to convene donor governments, multilateral institutions, NG0s,',
#  'mark: World Health Organization Regional Office for',
#  'construction line of settlements in Judea & Samaria." However, there never were any "agreed principles of settlement',
#  "Laura Rozen I Permalink I fA9ç%'1 Comments? Login or register",
#  'I am catching the next train',
#  'Sent: Thursday, March 25, 2010 11:21 PM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759666 Date: 06/30/2015',
#  'To: Mills, Cheryl D; Mills Cheryl',
#  'would advise people to deploy reputable anti-virus and anti-spyware programs on their computers, to',
#  'advance of the release expected in the next few days.',
#  'Subject: FW: 2 Aspen-event related questions',
#  'This piece appears today, June 10, 2010, in Mr. Davis\'s regular weekly column in The Hill "Purple Nation" and "The Daily',
#  '- worry about the rains and cont need for shelter (been raining in PauP for last 3 days).',
#  'page on the political horrors of 2010 for his party and the nation. But before then, Republicans are almost certainly going',
#  'Entergy',
#  '1111111111111111111111,',
#  'was a long way to go before politicians fully addressed what that might involve. Hence the argument that we needed -',
#  'Sent: Thursday, February 11, 2010 12:49 PM',
#  'Subject: FW: Note to Son Summit Preparation',
#  'set up the surgery last week at Bethesda.',
#  "To: irmt_haitieq_ovc@ofda.gov'",
#  'fan.',
#  'Forum commentary <http://blogs.usatoday.com/oped/forum_commentary/> I',
#  'chronic conditions among the 25 ac-',
#  'Sent: Sat Sep 19 09:10:17 2009',
#  'Arabia would be important. It is all the more so in an era when we Americans are at war with',
#  'From: White House Press Office',
#  'At the same time, it is important to avoid appearing to endorse any candidate in the June 20 runoff elections. Between',
#  'Before working at CGD, Radelet was a founding co-chair of the Modernizing Foreign Assistance Network. He was Deputy',
#  'Despite having the largest majorities of any party since the 1970s, Democrats put the brakes on their agenda, particularly',
#  'prepared for every possible contingency," he said in the interview. "That is what we have done from day one, while',
#  'Catholic Bishops, Stupak went a',
#  'Others are former Palestinian Authority police.',
#  'before we leave and make subsequent aid contingent upon maintenance of a strong presence for women in the Afghan',
#  'community is an incestuous one, making',
#  'process that takes place in bazaars between strangers who may never see each',
#  'Pls show S:',
#  '•Fear of another terrorist attack has increased since the attempted attack on a Northwest Airlines flight from Amsterdam',
#  'Today is',
#  'Mar 31st 2010',
#  'was Mr. Deese who spoke out strongly against simply letting the company go into liquidation, according to several',
#  'papers; identify things they think we should pursue; and add ideas — especially creative and far-reaching ideas — on top',
#  'sides. The President and cabinet members would constrain their',
#  'SL Green/Hard Rock (4-1) - Boosted its bid to $275 million, and has the Hard Rock brand name as mentioned',
#  'and advisory teams if dictators like Assad fall.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766967 Date: 08/31/2015',
#  '12 (b) GUIDELINES FOR PROGRAM FUNDS.-',
#  'Sounds real--cross your fingers. Let me know what you hear.',
#  'Swat refugee crisis.',
#  'Sent: Thursday, September 16, 2010 5:27 PM',
#  'Subject: FW: NHL scores big PD win in St. Pete!',
#  'Holbrooke',
#  "Particularly galling for Pakistan's middle class is the lack of a federal tax on agriculture, an industry that employs nearly half of",
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05762975 Date: 06/30/2015',
#  'Panetta acknowledges that there are',
#  'Crowley, Philip J',
#  'inspector general, and Paul Pillar, a former',
#  'his export conference this fall. You met him at the business roundtable lunch lorraine hariton organized on july 16th for',
#  'organization. You, Potus (ret) and whomever you would like to bring are invited to either or',
#  'Sent: Sunday, March 21, 2010 8:51 PM',
#  'Sent: Tue Apr 06 10:26:14 2010',
#  'Fw: H: New memo: Qs secret bid to UK. Sid',
#  'In preparation for a presidential delegation, EAP has recommended the following individuals to serve as delegates.',
#  "Qaddafi's forces. They also believe that the French, British, and other European countries will",
#  'former UK ambassador to the US Christopher Meyer has published his new book on the history of UK diplomacy with',
#  'To: Harris, Jennifer M',
#  "What's status of Agreement?",
#  'From: Samuelson, Heather F',
#  'responsible for advancing U.S. export and trade opportunities around the world. Republican staff under Sen..',
#  '174',
#  'I have been reporting on the American military for thirty years. My work on the Joint Chiefs of Staff, Four Stars, is',
#  "to enact hope and change will return in 2010 to keep hope alive. But the personal nature of Obama's victory is starting to",
#  'opportunity. The pursuit for opening doors of happiness for those who struggle with the unimaginable. The steady. The',
#  'Sent: Friday, April 24, 2009 2:38 PM',
#  'tenure, or not?',
#  'have long completed their sentences or never served time but now face deportation',
#  '"Those who created this trashy film do not represent the people of America or the Christian faith. The only',
#  'Raymond, who works with the advocacy',
#  'Fw: Government denies reports bomber to be freed',
#  'rhetoric that the U.S. and Colombia have military aspirations in the region.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759594 Date: 06/30/2015',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764701 Date: 07/31/2015',
#  'vital source of information, need to know.',
#  '— I knew that he has a lot of other demands on his thne, and I was going over to the Rose Garden and then I said, "Mr. President, can —',
#  "Here's what actually went on late last Friday night, as heads of state from two dozen countries met behind closed doors.",
#  'Sent: Saturday, September 15, 2012 06:38 PM',
#  'troops are meant to have been pulled off the streets, especially in nationalist areas.',
#  'WHA/FO:MDRUCKER - OK',
#  'contact Nora Toiv (ToivNF@state.gov) or Joanne Laszczych, (Laszczychi@state.gov) at 202-647-5548.',
#  'O Working with bureaus on end-of-year reports follow-up',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05775264 Date: 08/31/2015',
#  'Much of the blame on the failure to combat global hunger is because',
#  '20 (i) criteria for selecting foreign assist-',
#  'the national security." Once again, he was',
#  "Doing so will require significant help. The electoral council's headquarters were destroyed and its records lost in",
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764963 Date: 07/31/2015',
#  '5:25 pm PHONE INTERVIEW w/JESSLE LICHTENSTEIN, NYT MAGAZINE',
#  'I believe the conversations were very important and productive, and more importantly, so do the survivors with whom',
#  'economy.',
#  'Sent: Monday, October 19, 2009 6:02 PM',
#  'From: Ben Kobren',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045113',
#  'Ok - I am sending huma a revised call grid this afternoon.',
#  "more a distancing from New Labour. Ed's use of Iraq as an issue is symbolic of",
#  'Subject: (SBU) Amcit detained for explosives threat on flight from Taipei to Shanghai • During China Airlines flight',
#  'current fighting results in deaths, either of demonstrators, U.S. diplomats, Egyptian security',
#  'Sent: Saturday, September 12, 2009 11:55 AM',
#  "Following up on the discussion in yesterday's policy committee meeting about North Korea, I thought some of you might",
#  '6 and programs of the United States Government are',
#  "In a speech Monday, former Governor Mitt Romneywill criticize President Barack Obama's handling of the",
#  'To: Steinberg, James B; Lew, Jacob J; Mills, Cheryl D; Sullivan, Jacob 3; Chollet, Derek H; Abedin, Huma',
#  '** BBC Daily E-mail **',
#  'Information on AF/PDPA staffing is found in Annex III',
#  '150.)',
#  'serve concurrently and without additional compensation as',
#  'That said, Jalil continues to agree with el Keib that Ben Yezza is an excellent administrator, and in the long run will play',
#  'ministries are up and running as usual.',
#  'Sent: Sep 15, 2009 8:39 AM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05772219 Date: 08/31/2015',
#  'prohibited and may be unlawful. Any opinions expressed in this e-mail are those of the author and do not necessarily reflect the position of the United States Government.',
#  "about this particular derivatives rule, I'm not sure that I'm satisfied with that. And, gosh, we haven't yet brought",
#  'parallels Mexico today.',
#  'the way, that Bermuda has done us a great service, as well, on that front,',
#  'We are setting you up to meet with UN tomorrow - it will be Mulet (he is ne Heda Anabi) and we also will have UN',
#  'thinking or mitigated that resentment.',
#  'within the country who need outreach and support to "stand up and be who they are."',
#  '3:10 pm ASSISTANT MID-YEAR CONFERENCE Dean Acheson Auditorium',
#  'several villages, McClatchy reported. Most recently, on June',
#  '10:00 pm (t) DEPART Rodham Home *En route Private Residence',
#  'best practices. Nonprofits and governments have worked together to build great schools in many places in Africa,',
#  '- We condemn the effort to remove Zelaya from office.',
#  'Subject: Fw: A Bold New Strategy for Smart Aid',
#  'Sent: Sunday, October 14, 2012 09:45 AM',
#  'Given that E/EEB previously had the lead on energy matters before we had an International Energy Coordinator, I want',
#  'governmental functions in an area of combat operations."27 This language was watered down',
#  'me to join in celebrating It was a truly wonderful evening. B6',
#  'Cansen Basaran Symes: Member',
#  'Sent: Thursday, February 11, 2010 10:59 AM',
#  'Oxford University',
#  'Newspapers/b/ref=sa_menu_knews3?ie=UTF8&node=1263068011>',
#  'Sent: Tuesday, April 27, 2010 11:25 PM',
#  'Pis print and give copy to Eric and one to me.',
#  "where assorted music awards and platinum records are everywhere; where there's a discreet little skull in the middle of",
#  'military, or any of the other Whitehall departments involved in the Afghan',
#  'International Disaster Relief Fund... One of the principles is Craig Fant. Their operation is on the Gulf Coast. The',
#  'of the Israeli-Palestinian conflict. In Western Europe, while substantial majorities support U.S. anti-terrorism efforts,',
#  'To: Mills, Cheryl D; Valenzuela, Arturo A; Curtis, Meghann A; Kelly, Craig A; Brigety, Reuben; Shannon, Thomas A; B1',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05770135 Date: 08/31/2015',
#  'Rich reports that Kurt, Ellen Tauscher and Dan Rooney were confirmed tonight!',
#  'Sent: Saturday, April 3, 2010 8:18 AM',
#  'days; certification is expected as early as Friday. Tymoshenko, who has been silent publicly,',
#  'Subject: Fw: Ye of little FAITH: Hello from INTERPOL',
#  '18 orities, including priorities over 5- and 10-year time',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045735',
#  'Attachments: Global Burden Chronic Disease.pdf; Global Burden Chronic Disease.pdf',
#  'Cheryl is not ready for a secure call yet.',
#  'were made (though a couple of house members were unavailable). We have also been in touch with all leadership and',
#  'Constantinople in which a Greek Orthodox cleric was injured.',
#  'Subject: update on general jones',
#  'region and the lack of access to electricity in the rural countryside. Energy poverty, energy inefficiency and',
#  'Still, the police stood their ground and fought off the assault, and they kept their valuable suspect in',
#  'digestible in small bites by teachers with limited resources;',
#  '13 including options to outsource the entirety of the',
#  "popularity and playing to public opinion. Clegg is pushing off both Brown (still suffering from Obama's dismissive slights,",
#  'MFAN even has a running counter on its website tracking the days since President Obama pledged to release hi;',
#  'that claims to educate Jews',
#  "The senator's full remarks as prepared are below:",
#  'billion dollars, all in return for an Israeli commitment to freeze settlement construction for just three months,',
#  'From: Nancy Parrish',
#  'Sent: Mon Sep 27 09:41:01 2010',
#  'more years like the last four years," Romney will say. "The 21st century can and must be an American century. It',
#  '• Maintain natural resources so the land can be farmed well into the future and we can',
#  'In good news, the Brazilian Central Authority reported that the judge assigned to hear the two motions filed by',
#  'From: Keshap, Atul',
#  "Wilson's rebel yell at Obama has electrified the Republican grassroots, filling his campaign coffers with donations <a",
#  'Re: Plans of new Libyan PM',
#  'you have any questions, please call me direct at',
#  'We are waiting for DRL to clear the language. I will call Mike and/or Karen now. Everyone else is comfortable. Then we',
#  'had to build and some of the repair work we had to do, we had to travel."',
#  'Youth volunteers extract belongings from village homes as bulldozers move in',
#  '41',
#  'Sent: Thursday, August 12, 2010 10:57 PM',
#  'interview.',
#  '; Anderson, Gerald C; Koh, Harold Hongju',
#  '> good.',
#  '> should probably mention ECPA), a good energy example per David',
#  'against their perceived enemies. In fact, part of his appeal stemmed from his repudiation of partisan rancor -- there were',
#  "consulting firm), served as an advisor to the City of Philadelphia's Public Health Commissioner, and worked at",
#  'Ambassadors Robert Gelbard and James Dobbins',
#  "In response to the panel's findings, Secretary of State Hillary Rodhana Clinton said in a letter to Congress",
#  'Sent: Wed Apr 29 03:37:25 2009',
#  'The Global Power Elite and the World They Are Making" and "Running the World: The Inside Story of the NSC and the',
#  'a surprise defeat. "I can\'t prove it, but I think I was probably their victim,"',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05764008 Date: 07/31/2015',
#  '" Ibid., 272-273.',
#  '5. Enlarge the frame; re-focus attention on the main priority: a successful',
#  "internationalism. That's the difference b/w a strategy and a slogan. The principled and pragmatic",
#  'this, not least to condemn violence against a democratically elected head of state. It would be awkward',
#  'shaped by AF/PDPA.',
#  'around the worst economic crisis since the Great Depression. They are starkly variable crises, but some',
#  'country in a libertarian. direction. Among the institutions that they have subsidized are the Institute for Justice, which files.',
#  'Subject: G-20 Communiqué Preview for S',
#  'From: Cindy Akins',
#  'wasting fireball.',
#  'electronic means. Any such intention or agreement is hereby expressly disclaimed unless otherwise specifically',
#  'only Gadjah Made University in Yogyakarta was well set up to receive U.S. students and able to offer a significant',
#  'Sent: Monday, October 26, 2009 7:47 AM',
#  '1:25 pm ARRIVE Private Residence',
#  'Sent: Tuesday, April 20, 2010 7:04 AM',
#  'Thursday, December 10,',
#  'have to expand our engagement to reach and influence wider and more diverse groups using new',
#  'advised dialogue at a political level. But this is just FYI.',
#  '3:00 pm DROP-BY THE FULBRIGHT FOREIGN LANGUAGE TEACHING',
#  'Sent: Wednesday, April 7, 2010 7:49 AM',
#  'To: alemarahl<',
#  'On Mon, Apr 27, 2009 at 5:57 PM, H <HDR22@clintonemai1.com> wrote:',
#  'Brooke Shearer',
#  'many in the region now fear may soon extend to Yemen. Saudi counter-terrorism specialists, Who have a well-',
#  'To: Sullivan, Jacobi; Abedin, Huma',
#  'Defamation League chimed.',
#  'Sent: Thursday, June 25, 2009 7:24 AM',
#  'supporting the pro-democracy "green movement" that the U.S. State Department contacted corporate',
#  "Subject: Re: Branch's book",
#  'Subject: Call List',
#  '• Support the development of health systems that support healthier societies and confront the spread of pandemic',
#  'senior assistants condemn the Netanyahu government with growing severity. Secretary of',
#  'Sent: Thu May 06 19:18:12 2010',
#  'Nobody is going to indulge in rewriting [treaties for] many, many years. Nobody is going to play with the institutions again.',
#  'DPRK and their suspected hostile acts have been confirmed by evidence and their',
#  'broad-based development occurs, people are more likely to demand a say in securing their futures, and governments',
#  '16_a_sea_of filth_near_ground_zer0_mosque_gets_all_the_press_but_porns_around_corne.html> everything from',
#  'several authors," we arrive at this question:',
#  'Sent: Sun Mar 29 13:08:39 2009',
#  '"The USGLC applauds the President\'s nomination of Dr. Rajiv Shah to be USAID Administrator as yet',
#  'At two-forty-five in the morning, Reid suddenly declared the Senate adjourned. The Senate parliamentarian had just',
#  'that took place in Washington, DC last week, said that at various times the GOP strategists referred to',
#  'democracy demands."',
#  '7:05 pin DEPART State Department *En route Shiloh Baptist Church',
#  'Subject: PA Germany Restructuring',
#  'either works -- I can talk now and I can talk tomorrow am too - you want me to call?',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05774712 Date: 08/31/2015',
#  'principles to countries that were not present at the summit. The event will also',
#  'Introduction of Speaker: John Norton Moore',
#  'Sent: Saturday, September 4, 2010 11:24 AM',
#  'PSA faces the less daunting task of monitoring the overall performance of each delivery',
#  'to what their own fame and wealth can accomplish. "My goal is to go to places where my being there won\'t cause',
#  '"So I just, for anyone listening to this, it is not like there is no standard," she concluded. "There is a standard in',
#  'Egyptian President Mohammed rvlorsi, military and security forces are taking steps to detain or',
#  'Attachments: Pre Trip Pak Media (2).docx',
#  "Cc:,'",
#  'Abbas replied that "we\'re serious and our goal is to achieve a peace agreement as soon as possible." To this Peres',
#  'later, Preval told reporters he had no intention of complying with the rest, including changing the election body, known',
#  "To: eabedinh@state.gov'",
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045395',
#  'Towards Central Asia, towards Russia, they have deep fears. Towards America, it has become a relationship',
#  'have been conducted by officers of the British Special Intelligence Service (SIS / In the opinion of these',
#  'Office: (505) 476-2245',
#  '• (SBU) Embassy buildings are stable, with running water and electricity. Two Embassy officers and a',
#  'failure to report income from and pay taxes on a villa in the Dominican Republic and his ties to a real-estate developer',
#  'We are delighted to announce that for our opening night on Friday, March 12, at the Hudson Theatre in Manhattan, we',
#  'Fyi on Amb. Llorens readout from CODEL Mack.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05768486 Date: 08/31/2015',
#  'On behalf of FISA, Ms. Delaney has changed the local landscape not only by funding projects with',
#  'Subject: What time can we offer karzai for tomorrow?',
#  'Ok--but when are we scheduled top talk? Also pls send me five main points of my speech to summarize our goals. I want',
#  'Stiglitz has one more practical solution to offer. Governments should set up',
#  'numerous other GOL. efforts on this He expressed concern about the approximately 17,000 criminals released by',
#  'G. Align resources with policy priorities and stretch resources via partnerships with',
#  'Penny L. Price',
#  'theme is that when Baktash disregards Kamran\'s counsel, he usually gets injured within the next few scenes. "He',
#  "I haven't been able to get in. I emailed huma and she hasn't responded.",
#  'support for Copenhagen to the Brazilians.',
#  'the U.S.',
#  'Crown Prince Sultan to run the country in his absence. Sultan, thought to be in his mid-eighties, has had unspecified',
#  'ins and outs of the new Libyan politics in sufficient detail to give a view as to the accuracy of this report A few bits',
#  'Partnerships.',
#  'Behaviors that characterize the pattern.',
#  'Moreover, the international economic issues of greatest interest to U.S. businesses are precisely the ones that are being',
#  'Do you have her contact info? Thx.',
#  'sometime in the next few days.',
#  'The measures the Europeans are considering include bans on new Iranian bank branches in the EU, correspondent',
#  'meetings with Bibi and Abbas, you will be drawn into detailed discussions over the',
#  'requiring voting in some centers to be postponed for a few hours). Factoring in time to tally votes and process appeals,',
#  'on August 28 and WHA would like the letter sent as soon as possible so that it can be read and processed before the',
#  'countries have warned they would not recognize the vote unless Zelaya is restored beforehand. The United States has',
#  "fewer night raids — had been interpreted by the Taliban as signalling weakness on NATO's part. In",
#  'Subject: Call paul',
#  'persuasions. This experience, joined with Islamic piety, reinforces a Saudi insistence',
#  'Department has promised repeatedly to strengthen its oversight.8 Yet, as in Iraq, the Department',
#  'poverty of southern Mexico to work for about $10 a day in one of the many foreign-owned assembly plants known as',
#  'Subject Fw: (Reuters) UN council to vote June 9 on Iran',
#  'Obama should seize this chance to adjust his foreign policy.',
#  'SENSUTIVE BUT UNCLASSIFIED',
#  'outsider status was actually an advantage:',
#  'Sent: Monday, February 8, 2010 3:13 PM',
#  'affected area. As I noted, even though Otunbayeva made a public statement on June 15 to the effect that foreign',
#  "> of John Boehner's tan?",
#  'Defendants\' profit margin."29 This is a clear example of the contractor endangering the U.S.',
#  'Ms:',
#  'Since the Goldises arrived, six Israeli prime ministers have held peace talks with the Palestinians. Some have officially',
#  "I'm seeing Yunus tom'w. We're both speaking to the Hilton Foundation. He wants to meet with me there. I will learn",
#  'Original Message ---- .',
#  'Sounds like a tuff day in Canada. Sorry you have such a incredibly hard job but we do appreciate all you do.',
#  'the concerns of vandalizations of Orthodox churches and monasteries of the Ecumenical Patriarchate by Turkish',
#  'Sent: Monday, May 31, 2010 2:16 AM',
#  'Finally I had an excellent meeting today with Pat Kennedy. He offered to help me',
#  "Osborne's first Budget? It's wrong, wrong, wrong!",
#  'Nonetheless, Abdullah has now set Saturday as the date for his address to the nation, and Karzai clearly wants both for',
#  'Islamist dissidents taking advantage of the current situation to carry out attacks that demonstrate his',
#  'coming to Pakistan in the fall and be looking to do the exact same thing with Pakistan.',
#  'By SUZAN CLARICE',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766273 Date: 07/31/2015',
#  "leadership role in implementing this plan. AF/PDPA's leadership team (Director, Deputy,",
#  'Relations <http://www.cfr.org/> , was the first time we have been given an',
#  'Lots of White House officials observed Bob Woodward, Mr. First Draft of History, repeatedly and boldly slipping behind the',
#  'Elections: The Swedish Ambassador told me she will be meeting with the Supreme Electoral Tribunal and discuss the',
#  'movement. Bruce Bartlett, a conservative economist and a historian, who once',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766683 Date: 08/31/2015',
#  'Is he at your house this weekend?',
#  "'peter.quilter@mail.house.gov'; lanice.kaguyutan@mail.house.gov1; 'Noonan, Mary McDermott'; Hickey, Mary E; 'Ricardo",
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05775250 Date: 08/31/2015',
#  '1.4(D',
#  'From jake.sullivan',
#  'sentiments of voters in rural',
#  'pious fallen martyrs, etc.-- another sign that this movement is not just alienated secularized elites.',
#  'the United States is, in fact, the indispensable nation. Sometimes for bad reasons and, other times, as in Haiti, for good',
#  'the ICTR to Rwanda and he also had recently completed a trial in which he announced he was going to be filing an',
#  'Some polls late last week suggested the Conservative lead had grown rather than shrunk, and research may have been',
#  '24 tiveness.',
#  '- an increase of four percent over the FY 2009 total, including the Spring Supplemental',
#  '1, 2009, a total of $135,008 in private donations from U.S. sources for',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05761174 Date: 06/30/2015',
#  'Aid: 800-462-1944 begin_of_the_skype_highlighting 800-462-1944 end_of_the_skype_highlighting',
#  '7:15 pm (t) Jefferson and Adams Rooms, eFloor',
#  '/200348_summit/summit_documents/health_-_a',
#  'Sent: Fri Feb 12 13:58:15 2010',
#  "To: 'hdr22@clintonemail.comi <hdr22@clintonemail.com>",
#  'Sent: Friday, December 4, 2009 1:03 PM',
#  'Enterprise Rent-a-Car',
#  'This is a significant change in US stance on Bangladesh. Not very long ago, the US Ambassador to Bangladesh Harry',
#  "through job training, etc.). In short, they're too nice. Many Haitians have never held a regular job, are unfamiliar with",
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763588 Date: 07/31/2015',
#  'Sent: Saturday, May 15, 2010 8:39 PM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05771668 Date: 08/31/2015',
#  'world of people who thought the New Deal was a horrible mistake." According to diZerega, Charles supported the school',
#  "Reserve and the I.R.S. The Tea Party's fulminations against cap-and-trade, federal-government bailouts, and big",
#  'deadlines for timely prosecution have run out. Since their arrest in late 2008, their case has been prolonged by',
#  '-Swedish Foreign Minister Bildt at 9:00 am',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05770790 Date: 08/31/2015',
#  'SECRETARY CLINTON: We wanted --',
#  'Room.',
#  'Sent: Sat May 09 07:16:58 2009',
#  'The document, obtained by the Observer, is headed "draft letter from Foreign Secretary to Prime Minister" and',
#  'endorsement of hosting and international exchange. I opened the email and clicked on the link. The two receptionists, a',
#  '1A',
#  ',72,83,93,100,110,150,466,570,907,913,926,1283,1335,1389,1454,1461,1576,1667,1679,1748,1749,1794,1837,1866,19',
#  'Q. How much money has been raised through the texting campaign for humanitarian aid for',
#  'who is often narrowing their options.',
#  'disapproved of the release of the Lockerbie bomber on compassionate grounds, something No 10 had not',
#  'Subject FW: Update on UN',
#  "Obama has to find a way to coax each of them toward a change of course. Public bullying won't do it.",
#  'disappeared. With the Federal Reserve cautious, too, the likelihood of a lengthy period of weak growth and heavy',
#  'party were about to offer effective government as a solution to multiple problems after 30 years of solid branding',
#  '11:00 am MEETING w/SPECIAL ENVOY SCOTT GRATION',
#  'ing these two observations in mind, it is clear',
#  'Sent: Tue Jan 19 21:24:50 2010',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05768358 Date: 08/31/2015',
#  '107',
#  'our security.',
#  'Sea, and a spike in world food prices cause jitters on Wall Street and worries about our future',
#  'President Mohammed Yussef el Magariaf, and they had all agreed that military and security',
#  'Fmr. Amb. Chas Freeman, whom I know is on the outs w/ us but who nevertheless merits the respect of many of the',
#  '16, (ii) any private, entity or person in the',
#  "(Sarko now saying he won't send any new troops while Brown has",
#  'Treasury has been as effective on China as it has been on AIG. Just thoughts of an observer.',
#  'Sent: Saturday, October 24, 2009 1:46 PM',
#  'they wanted to avoid," Gude says. "The',
#  'Arab-Israeli peace talks.',
#  'answers. We believe there are compelling reasons Republicans should support ratification.',
#  'no other scholar in the state or elsewhere—to testify as a "neutral expert" on the legal impact',
#  'humanitarian crisis that has emerged in the south. First, the crisis probably has its origins in a raw struggle for power.',
#  'AQ',
#  'The decision was not an easy one. First, Madam Secretary, you know when we first met: Believe it or not, it has been',
#  'expertise and advice in helping us do our jobs as well as we can to serve',
#  'the hours for your party?',
#  'publicized book. Torat',
#  'Subject: Fw: (VON HAP) North Korea: Nuclear Test',
#  'Washington, 1). C. 20.52(1',
#  'Her daughter Preetha, as you may know, started in Iowa and stayed on in campaign as volunteer all the way through',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05772118 Date: 08/31/2015',
#  'lost it early," said Rendell, an ardent Hillary Clinton backer who later became an Obama supporter. "We didn\'t',
#  'education. Women now make up 58 percent of the enrollment in Saudi universities. The new Princess Noura bint',
#  'these Western entities, using them as a weapon to weaken the el-Keib regime. This trend is also',
#  "result of HRC's call. In any event, I'm around this week, though hanging out as much as",
#  '• Work with the Chiefs of Missions and other diplomats in countries where capacity',
#  'Subject: FW: Call to Cheryl Mills from Dr. Muhammad Daoud Miraki.',
#  'Cc: Helfet<',
#  'this challenge."',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05767098 Date: 08/31/2015',
#  'institute of learning: the online, for-profit Beck University. Enrollees can take courses like Faith 102, which contends with',
#  'Just adopted the last amendment...could vote in the next hour or two. Still waiting for a uc agreement to lock in a time',
#  'hostility towards Israel.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05774051 Date: 08/31/2015',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05771611 Date: 08/31/2015',
#  'settlements, Mr Netanyahu forced himself to utter the words "Palestinian state"',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05766168 Date: 08/31/2015',
#  '>; williamsbarrett',
#  'Subject: Re: Tom Buffenbarger',
#  'recovery, especially in Haiti, where natural disasters have caused',
#  'Thursday, May 6, 2010 3:18 PM',
#  'Cc: Hale, David M; Rudman, Mara; Reed, Julia G',
#  'My traveling companions, Bill Roebuck (NEA/MAG director) and Ben Fishman from the NSS, start their return trip today.',
#  'DRAFT — DRAFT — DRAFT',
#  'compared to the 2005 election. There is little correlation in provincial level',
#  'said no.',
#  'remarkable Eric Rasmussen, MD, MDM, FACP CEO of the Google-founded humanitarian NGO called',
#  'US objectives as well as resulted in substantially greater fairness for a former territory, now freely associated state. Jeff',
#  'the people of Berlin as though freedom could be contained in only one part of the city. Here, in Berlin, the Cold',
#  'general is politically independent, and',
#  '• The frequently-announced press conference by the Brazilian family/their attorney never materialized. We await',
#  'Regards, Odeh',
#  'think they will want to do that. So as they now become stronger and more powerful, I believe that while their',
#  '6:25 pm (t) ARRIVE Private Residence ###',
#  'Subject: (AP) Fate of Mideast talks in hands of polarizing rabbi',
#  'making it happen, there would have been no video. Katie, your constant can-do attitude, hectoring to get us',
#  'measures to create a desired political outcome of stability, and if possible democracy. . . . if a',
#  'From: Verma, Richard R [mailto:VermaRR@state.gov]',
#  '<http://www.tdbimg.com//image/print footer.gif?v=7.73.13>',
#  'relationship with Iran, are subjects she can put on the table and make sure are comprehensively considered before any',
#  "Subject: PM Bellerive on Donors' Conference, SOFA, adoptions, migrants, political dilema and more",
#  'and to respond to complaints about their content that are received by the ministry of culture and information.',
#  'GATES AND JCS CHMN MULLEN 106 Dirksen Senate Office Building',
#  'From: Lou de Baca, G/TIP',
# ...
#  "To: 'sbwhoeop(",
#  'Sent: Tue Sep 01 16:35:31 2009',
#  '"We never considered using the brigades," he said, referring to the 17th of February Brigade, the local militia',
#  'Afghanistan forward.',
#  'ensure a first or second place finish on Feb. 22, followed by a campaign of about $3 million for the April runoff.',
#  '- DDR: Abushagur said there are three main groups of militants to',
#  '6. Stewart BW, Kleihaus P, eds. World Cancer Re-',
#  'Sent: Thu Aug 26 05:59:20 2010',
#  'WJC told Gore to ignore reporting that he was offended or critical of his campaign. "On tape, the president said he',
#  "leadership/ownership/stewardship of this country's libya policy from start to finish, let me know what you",
#  'constitution... ...the work you have undertaken... We want the resolution to go through. We do appreciate the work',
#  'Nov. 6. "An increased U.S. and foreign role in security and governance will increase',
#  'or the foreign minister or an ambassador," she tells me a few weeks later, as she perches on a sofa in her',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05759745 Date: 06/30/2015',
#  'infrastructure. And there are aggressive incentives directed at exporters (i.e., tax rebates, "buy China" procurement',
#  'other Americans were killed at the U.S. Consulate in Benghazi, Libya, an attack',
#  'Fiona McCoy',
#  'old billionaire being accused of paying British attorney David Mills $600,000 in 1997 to',
#  'support local solutions and focus on long-term sustainability to help people feed themselves and',
#  'Cc: Campbell, Piper',
#  "What have we to gain from humiliating our partner before his constituency on the way to the negotiating table? If Israel's",
#  'A trial has begun in Turkey of influential people alleged to be part of an ultra-nationalist group, Ergenekon. Otmar',
#  'Dear members of Team Pledge Data,',
#  'chorage, Alaska, to give her a more exact time for our arrival.',
#  'Sent: Sat Jan 1622:00:42 2010',
#  'ask my country to go extinct?" demanded Nasheed. The Chinese delegate feigned great offence — and the number',
#  'and suggests that he was gay.',
#  'The problem starts at the top. The average worth of Pakistani members of Parliament is $900,000, with its richest member topping $37',
#  'early-warning detection system is, after all, based at RAF Fylingdales on the North Yorkshire Moors)?',
#  '"When my son told me he was gay, I told him, \'Now, I love you more.\' I want to tell the world that hatred is not',
#  'Doc No. C05739731',
#  'detailed plan for achieving those objectives, and the very specific, measurable metrics being used to measure progress',
#  'Performance Indicators: clips have increased utility/importance to readers (reader',
#  'authoritatively, embracing her partners on both sides, and reminding the world of the difficulties to be expected',
#  'no partner and no bridge to Europe, where the Merkel government has entered a fugue state of vertigo (another',
#  '<http://the-acap.oreacap-enabled.php>',
#  "domestic Jewish support for incumbent presidents. Of course, there hasn't been an",
#  'From: Crowley, Philip1 <CrowleyR1@state.gov>',
#  'on the ASEAN plus three (China, Japan, Korea), harking back to (former Malaysian prime minister) Mahathir',
#  'said in a phone interview yesterday.',
#  'the public. And not just conservative: William S. White, in his 1956 book "Citadel," called the Senate "to a most peculiar',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05769799 Date: 08/31/2015',
#  'http://www.washingtontimes.com/news/2009/jul/13/netanyahus-speech-for-peace-is-anyone-',
#  'who had called me last week. was following up to visit about and confirm his',
#  'Article License: Copyright - Article License Holder: ICRW',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05770811 Date: 08/31/2015',
#  '• Confio en que el propio pueblo estadounidense rechace "el use abusivo" de sus recursos econornicos para lo que',
#  'cloture, and the vote on health care finally took place on Christmas Eve.)',
#  'b) The flow of persons across the border is constant, but no mass influx. However, official figures under-report',
#  "I thought we were moving him to Thursday but schedule I just got says tomorrow. What's status?",
#  'concerned by the possibility that the country may deteriorate into a multi-sided civil war involving the regional militias,',
#  'Sett McCain and I toured the new parliament this afternoon, where we encountered a TNC member, an engineer and a',
#  'wasted no time asserting his control. On a secure videoconference call last Saturday, a person familiar with the call said,',
#  '2. June 2011',
#  'Sent: 9/2/2010 1:07:36 P.M. Eastern Daylight Time',
#  'first time a major corporation used a cutout"—a front operation—"in a threatening way. Koch Industries was the poster child of',
#  'tion, March 2004).',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045505',
#  'population who could afford to pay for them. Consider, for example, that only about 28 percent of Haitians have access',
#  'real reason to hope. My hope, to be perfectly clear!, is that you will be a friend to as he navigates a system he has',
#  '"We have a policy for tardiness and she was tardy many times," Puchalsky said. "When she had arrived late to work her',
#  'guerrilla organizations have ever used Cuba as a site for terrorist or insurgent activities.',
#  '> Sent: Sat Oct 03 10:58:07 2009',
#  'Sent: Tuesday, June 22, 2010 9:19 AM',
#  'All,',
#  'this stronger than ever.',
#  "'peter.quilter@mail.house.gov% lanice.kaguyutan@mail.house.gov% 'Noonan, Mary McDermott'; Hickey, Mary E;",
#  "cause havoc with peace and economic recovery. I'd send a private message asap on that score the second a new",
#  'somehow bring extraordinary focus to each in turn. He says he was driven from the very beginning. "It was my decision',
#  'Sent: Fri Sep 24 05:16:14 2010',
#  'McEwen recalled him telling her.',
#  'Classified by DAS, A/GIS, DoS on 07/30/2015 — Class: CONFIDENTIAL — Reason: 1.4(B), 1.4(D)',
#  'even greater toughness. The conservative operative Grover Norquist, who is known',
#  'Jalil believes the LMB/JCB will have a significant role in the new government, possibly',
#  'Sent: Wednesday, April 01, 2009 11:59 AM',
#  'surface that his job was in danger. Non-denial denials were issued from the White House.',
#  'Subject Fw: European Parliament',
#  'Canadian and UK governments to develop internationally-recognized travel documents for the Iroquois nation as well as',
#  'soldier that finally I can deal with.\'"',
#  'Advisor',
#  'are killed or disabled. Ensure adequate lasting medical care for lasting injuries.',
#  'Subject: What is this meeting about?',
#  'Sent: Sat Aug 29 13:50:39 2009',
#  'America safer.',
#  'Oh, and after confirming to do so with PIR, did a quickie recalling the thoroughly positive vibes and experiences of you',
#  'Sent: Fri Jan 29 23:58:58 2010',
#  'realize the objectives both share with most Americans: establishing',
#  'Doc No. C05739830',
#  'better way to end their people\'s suffering. Playing "peace process" charades justifies',
#  'possible establishment of that state; and (3) to achieve these in a manner that ensures the security of Israel and of the',
#  'Sent: Saturday, April 17, 2010 6:07 PM',
#  'Mandates all along this spectrum are strong',
#  'down the call, a breach of both manners and protocol. In his keenness to befriend Russian President Dmitry Medvedev,',
#  'on in the mainstream media.',
#  'Fax: 202.797.2461',
#  'Mr. Sami Abraham has worked for the Independent Media Group of Pakistan since 1996.',
#  'To view the Senate Democratic Floor Schedule, vote tallies, unanimous consent',
#  'Doc No. C05739762',
#  "After a Court Ruling, Berlusconi's Legal Woes Resume By Jeff Israely The world has spent the past six months wondering",
#  'REF: A. STATE 86734',
#  'senators have considered a radical option: mutiny.',
#  'focus of the stimulus is on its two most unbalanced sectors -- fixed investment and exports, which collectively account',
#  'Roemer, Tim J; White, Steven J; Schulz, Kirsten A; Gramaglia, Thomas R; Hartley, Brent R; Patterson, Anne W; S-SANAC-',
#  'Swedish Ambassador, who is resident in Guatemala, is here on a visit and plans to attend the Accord ceremony on',
#  'Petit Goave, including other regions such as Les Cayes and Nippes.',
#  'Sent: Tue Aug 24 18:00:03 2010',
#  'long-time supporter and acquaintance of Secretary Clinton and the former President. Please convey my best wishes and',
#  'Singh made a visit to Malaysia on October 26 on his way to the East Asia Summit in Hanoi. He met with',
#  'debriefing activities? I would say yes."',
#  'show he hosts. "We felt that the revolution is going in vain."',
#  'Sent: Monday, September 21, 2009 7:18 AM',
#  'for individuals charged with',
#  '> nations will follow suit; again, compare Durban.',
#  'Subject: Psychology and Middle East Peace',
#  'Sent: Monday, July 06, 2009 11:09 AM',
#  "organizations or so launched '4636' as an emergency number.",
#  'Fellow at the New America Foundation, and Senior Political Writer for The Daily Beast. His new book, The Icarus',
#  '"The key thing about Pete is that the president trusts him and would feel very, very',
#  '12:00 pm ON STATE/FOREIGN OPERATIONS Rayburn H.O.B. Room 2359',
#  '4 Isfahan 1,799,255 51,788 14,579 746,697 25162 2,637,481 2,612,319',
#  'http://www.time.comitime/specials/packages/article/0,28804,2023831_20238',
#  'Sent: Tuesday, February 9, 2010 10:50 AM',
#  'Secretary-',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045038',
#  'Re: also...',
#  'Obama was too cautious in fearful times',
#  'Subject: Fw: Pakistan',
#  '15 minutes talking to Empey by phone, according to BBC Northern Ireland.',
#  'democratic trend continues," she told the parliament.',
#  'there consists of traditional diplomacy — foreign-service officers helping Americans traveling or',
#  '4:15 pm BILATERAL MEETING w/INDIAN NATIONAL SECURITY ADVISOR',
#  "Hillary Clinton and Robert Gates, the president's secretaries of state and defence.",
#  'discuss it further. Rich',
#  '198',
#  'To: raj.shah rajivshah',
#  'From: Strobe Talbott [mailto',
#  'Sent: Tuesday, January 19, 2010 10:35 PM',
#  'Re: Bad news',
#  "the public option.' And she says, 'Well, dude, I can't get this done then.' So then he goes to Harry Reid and says, 'We're going with",
#  'to draw up a formal "coalition contract" — as happens in Germany — that would bind the Lib Dems and other',
#  'myriad of historical facts and coincidences. But it is there.',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05763787 Date: 06/30/2015',
#  'the "cokehead in chief." In an online thread, West speculated that the President was exhibiting symptoms of "demonic',
#  'holdover from the Bush administration, his national security bona fides are hard to dispute. It is no',
#  'Status update on the Chris Stevens mission to Benghazi:',
#  'I will try you ton ite',
#  'Institute—but he saved his political capital for his real goals: undoing the fiscal underpinnings of New Deal-style',
#  'Aceh terror suspect held in Malaysia. Indonesian authorities have confirmed that Taufik Marzuki,',
#  'In his autobiographical book The Audacity of Hope, Obama highlighted a key component of his political strategy: "I serve',
#  'Sent: Sunday, March 21, 2010 7:18 PM',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05762366 Date: 06/30/2015',
#  'and standby components that are being stepped up are drawn from State, USAID, and a core',
#  "Secretary of State Hillary Clinton's affirmation that protecting human rights is central to",
#  'opponents require the use of all 30 hours, post-cloture, they will finish the tax bill on Tuesday evening. It is possible',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045167',
#  'military. There is no indication that rebel Prime Minister Mahmoud Jabril, his senior aid Abdul',
#  'Subject: RE: Secure fax',
#  'Mahdi Ghazanfari said if the sanctions were really having an impact, then the UN would not have had to impose four',
#  'Cleared: INL: WJMcGlynn',
#  "Blair. Also, if done, should include description and endorsement of Blair's",
#  "Subject: (AP) Israeli PM: Current settlement curbs won't remain",
#  'Front: Tomlinson, Christina',
#  'that only about 28 percent of Haitians have access to health care, 50 percent have access',
#  'What about Holder? And the King?',
#  'never seen her back down. And I believe that she is now not physically well enough to testify',
#  'Sent: Saturday, November 7, 2009 6:12 AM',
#  '6 mittee on Foreign Relations of the Senate;',
#  'remarkable prosperity. The 2005 energy bill, which Hillary Clinton dubbed the Dick Cheney Lobbyist Energy Bill, offered',
#  'Subject: Re: Huff Post Renegade Excerpt',
#  'Obama, that somebody this bright, this respected, this good, and with this integrity, was',
#  '2201 C St NW Room 7261',
#  "Muslim Brotherhood's (MB) Justice and Construction Party (jCP), as well as certain of the other",
#  'Sent: Wednesday, September 2, 2009 6:05 AM',
#  "Cheryl, the General will be traveling during the November 20 Secretary's retreat. May I attend in his absence?",
#  'cases that merited prosecution, though',
#  'Free Triai',
#  'One thing I missed:',
#  '12:30 pm PHONE CALL w/PETER ROBINSON, FIRST MINISTER (T)',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05769275 Date: 08/31/2015',
#  'Egyptian population living immediately across the border with Libya.',
#  'be explained on the Hill and will be sustainable. I am on board to lead an energy policy dialogue in Pakistan on 10-20/21',
#  'Subject: Yoga',
#  'are also aiding in this extraordinary effort.',
#  'out of it not to realize that the Palestinians and Israelis were nowhere close to sitting down with each other and dealing.',
#  'Subject: To read on the trip back 2',
#  '1 • ating the effectiveness of foreign assistance',
#  'To: Steve Abbot.',
#  'Sent: Mon May 17 19:58:42 2010',
#  'IS a meeting possible Or maybe we could set up an initial phone',
#  'Sent: Sunday, January 3, 2010 6:37 PM',
#  'This leaves the',
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05762738 Date: 06/30/2015',
#  '• Partnering and Leading Through the Interagency',
#  'Saturday, October 17, 2009 6:15 AM',
#  'None of these candidates is,over 32 years old. The best writer among them is the youngest — 24. She is intellectually',
#  "about, frankly. There just aren't that many",
#  'Susana M; Nellis, Jonathan J; McConn, Beth D; Orjales, Rodolfo; Burton, Wade W; Fisk-Telchi, Mary F (Montevideo);',
#  'that she describes as "flat wrong."',
#  'Subject Re: Crowley',
#  'Whether that will happen in our lifetimes I can\'t say."',
#  "Cc: Cheryl Mills (State); 'Cheryl Mills'",
#  "Attachments: 2010.11.21.With settlement deal, U.S. will be rewarding Israel's bad",
#  "Senate Majority Leader Harry Reid's (D-Nev.) wife and daughter were in a car accident Thursday and taken to",
#  'UNCLASSIFIED U.S. Department of State Case No. F-2014-20439 Doc No. C05771880 Date: 08/31/2015',
#  'it is clear that governments (and indus-',
#  '202-647-5548.',
#  "Sarkozy's unleashed id is the barometer. You are still perceived as separate and even increasingly as",
#  'a press conference that',
#  'His distortions and fabrications are consistent with his approach throughout this sordid and criminal affair. Wasting his',
#  'mucking up the fight against HIV/AIDS before. Now, just as the South African government is finally changing',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-SCB0045165',
#  'Subject: From PauP',
#  'This memo has two parts. Part one is the report that Syria is providing air support for Qaddafi. Part two is a note',
#  '18)Andrew Rasiej, TechPresident',
#  "minimum international student enrollment of 5% in order to continue Indonesia's embrace of globalization nd",
#  'functions. The analysis of over a half dozen configurations for the public diplomacy country',
#  'Sent: Thursday, December 3, 2009 7:42 AM',
#  ...]

# %%
## We now try to extract as much sensible text as possible.
## To do so, we first get rid of the recurrent headers and metadata fields.

undesired = ['STATE DEPT. -','UNCLASSIFIED','From:','To:','Sent:','Doc No.','Case No.','Date:',\
             'RELEASE IN','PART ','Attachments:','For:','SUBJECT TO AGREEMENT ON SENSITIVE','',\
             'U.S. Department of State','Fw:','Fwd:','----- Original Message','B6','Re:','Cc:',\
             'Bcc', 'Subject:', 'RE:', 'FW:']


for line in email_lines:
    if(any(undes in line for undes in undesired)):
        email_lines.remove(line)

# %%
len(email_lines)
# Out:
# 84770

# %%
## Let us first create a raw corpus word cloud.

from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

# The whole text.
text = emails_raw

# read the mask image
hilary_mask = np.array(Image.open('mask.png'))

stopwords = set(STOPWORDS)
#stopwords.add("said")

wc = WordCloud(background_color="white", max_words=20000, mask=hilary_mask,
               stopwords=stopwords)
# generate word cloud
wc.generate(text)

# store to file
wc.to_file('Raw_cloud.png')

# show
plt.figure(figsize = (8,8))
plt.imshow(wc,cmap=plt.cm.gray )
plt.axis("off")
plt.show()

# %%
emails = ""
for line in email_lines:
    emails = emails + line + '\n'

# %%
## We tokenize and remove english stopwords
clean_email_words = list(set(nltk.word_tokenize(emails)) - set(nltk.corpus.stopwords.words('english')))

stemmed_email_words = ""
for word in clean_email_words:
    stemmed_email_words = stemmed_email_words + SnowballStemmer("english").stem(word) + '\n'

# %%
wc1 = WordCloud(background_color="white", max_words=20000, mask=hilary_mask,
               stopwords=stopwords)
# generate word cloud
wc1.generate(stemmed_email_words)

# store to file
wc1.to_file('Clean_cloud.png')

# show
plt.figure(figsize = (8,8))
plt.imshow(wc1, cmap=plt.cm.gray )
plt.axis("off")
plt.show()

# %%
## Yes there is a considerable difference, as the stopwords and the undesired words 
## (Subject Case Date etc) are removed and we have a cloud that represents the real 
## content of the messages, which is the purpose of the visualisation.

# %%
import pycountry

# %%
## Finding mentions of countries

# %%
countries_by_name = []

for word in clean_email_words:
    try:
        countries_by_name.append(pycountry.countries.get(name = word))
    except:
        pass

# %%
countries_by_name = list(set(countries_by_name))

# %%
len(countries_by_name)
# Out:
# 134

# %% [markdown]
# ### Checking for false negatives

# %%
countries_by_a2 = []

for word in clean_email_words:
    try:
        countries_by_a2.append(pycountry.countries.get(alpha_2 = word))
    except:
        pass
    
countries_by_a2 = list(set(countries_by_a2)) 
len(countries_by_a2)
# Out:
# 121

# %%
countries_by_a3 = []
for word in clean_email_words:
    try:
        countries_by_a3.append(pycountry.countries.get(alpha_3 = word))
    except:
        pass
countries_by_a3 = list(set(countries_by_a3)) 
len(countries_by_a3)
# Out:
# 30

# %%
pot_false_neg = []
pot_false_neg = pot_false_neg + list(set(countries_by_a2) - set(countries_by_name))
pot_false_neg = pot_false_neg + list(set(countries_by_a3) - set(countries_by_name))

pot_false_neg = list(set(pot_false_neg))

# %%
len(pot_false_neg)
# Out:
# 60

# %%
pot_false_neg
# Out:
# [Country(alpha_2='CV', alpha_3='CPV', name='Cabo Verde', numeric='132', official_name='Republic of Cabo Verde'),
#  Country(alpha_2='CD', alpha_3='COD', name='Congo, The Democratic Republic of the', numeric='180'),
#  Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643'),
#  Country(alpha_2='MU', alpha_3='MUS', name='Mauritius', numeric='480', official_name='Republic of Mauritius'),
#  Country(alpha_2='SL', alpha_3='SLE', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone'),
#  Country(alpha_2='VA', alpha_3='VAT', name='Holy See (Vatican City State)', numeric='336'),
#  Country(alpha_2='PR', alpha_3='PRI', name='Puerto Rico', numeric='630'),
#  Country(alpha_2='IO', alpha_3='IOT', name='British Indian Ocean Territory', numeric='086'),
#  Country(alpha_2='RE', alpha_3='REU', name='Réunion', numeric='638'),
#  Country(alpha_2='KM', alpha_3='COM', name='Comoros', numeric='174', official_name='Union of the Comoros'),
#  Country(alpha_2='BJ', alpha_3='BEN', name='Benin', numeric='204', official_name='Republic of Benin'),
#  Country(alpha_2='NF', alpha_3='NFK', name='Norfolk Island', numeric='574'),
#  Country(alpha_2='PM', alpha_3='SPM', name='Saint Pierre and Miquelon', numeric='666'),
#  Country(alpha_2='GB', alpha_3='GBR', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland'),
#  Country(alpha_2='HK', alpha_3='HKG', name='Hong Kong', numeric='344', official_name='Hong Kong Special Administrative Region of China'),
#  Country(alpha_2='HM', alpha_3='HMD', name='Heard Island and McDonald Islands', numeric='334'),
#  Country(alpha_2='MD', alpha_3='MDA', common_name='Moldova', name='Moldova, Republic of', numeric='498', official_name='Republic of Moldova'),
#  Country(alpha_2='AL', alpha_3='ALB', name='Albania', numeric='008', official_name='Republic of Albania'),
#  Country(alpha_2='LC', alpha_3='LCA', name='Saint Lucia', numeric='662'),
#  Country(alpha_2='CI', alpha_3='CIV', name="Côte d'Ivoire", numeric='384', official_name="Republic of Côte d'Ivoire"),
#  Country(alpha_2='TJ', alpha_3='TJK', name='Tajikistan', numeric='762', official_name='Republic of Tajikistan'),
#  Country(alpha_2='AI', alpha_3='AIA', name='Anguilla', numeric='660'),
#  Country(alpha_2='LI', alpha_3='LIE', name='Liechtenstein', numeric='438', official_name='Principality of Liechtenstein'),
#  Country(alpha_2='VI', alpha_3='VIR', name='Virgin Islands, U.S.', numeric='850', official_name='Virgin Islands of the United States'),
#  Country(alpha_2='CR', alpha_3='CRI', name='Costa Rica', numeric='188', official_name='Republic of Costa Rica'),
#  Country(alpha_2='BA', alpha_3='BIH', name='Bosnia and Herzegovina', numeric='070', official_name='Republic of Bosnia and Herzegovina'),
#  Country(alpha_2='MF', alpha_3='MAF', name='Saint Martin (French part)', numeric='663'),
#  Country(alpha_2='AS', alpha_3='ASM', name='American Samoa', numeric='016'),
#  Country(alpha_2='MK', alpha_3='MKD', name='Macedonia, Republic of', numeric='807', official_name='The Former Yugoslav Republic of Macedonia'),
#  Country(alpha_2='NC', alpha_3='NCL', name='New Caledonia', numeric='540'),
#  Country(alpha_2='VC', alpha_3='VCT', name='Saint Vincent and the Grenadines', numeric='670'),
#  Country(alpha_2='TT', alpha_3='TTO', name='Trinidad and Tobago', numeric='780', official_name='Republic of Trinidad and Tobago'),
#  Country(alpha_2='LA', alpha_3='LAO', name="Lao People's Democratic Republic", numeric='418'),
#  Country(alpha_2='TV', alpha_3='TUV', name='Tuvalu', numeric='798'),
#  Country(alpha_2='MS', alpha_3='MSR', name='Montserrat', numeric='500'),
#  Country(alpha_2='NZ', alpha_3='NZL', name='New Zealand', numeric='554'),
#  Country(alpha_2='TO', alpha_3='TON', name='Tonga', numeric='776', official_name='Kingdom of Tonga'),
#  Country(alpha_2='VU', alpha_3='VUT', name='Vanuatu', numeric='548', official_name='Republic of Vanuatu'),
#  Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410'),
#  Country(alpha_2='FO', alpha_3='FRO', name='Faroe Islands', numeric='234'),
#  Country(alpha_2='GF', alpha_3='GUF', name='French Guiana', numeric='254'),
#  Country(alpha_2='NR', alpha_3='NRU', name='Nauru', numeric='520', official_name='Republic of Nauru'),
#  Country(alpha_2='DO', alpha_3='DOM', name='Dominican Republic', numeric='214'),
#  Country(alpha_2='CC', alpha_3='CCK', name='Cocos (Keeling) Islands', numeric='166'),
#  Country(alpha_2='FM', alpha_3='FSM', name='Micronesia, Federated States of', numeric='583', official_name='Federated States of Micronesia'),
#  Country(alpha_2='PG', alpha_3='PNG', name='Papua New Guinea', numeric='598', official_name='Independent State of Papua New Guinea'),
#  Country(alpha_2='SM', alpha_3='SMR', name='San Marino', numeric='674', official_name='Republic of San Marino'),
#  Country(alpha_2='MP', alpha_3='MNP', name='Northern Mariana Islands', numeric='580', official_name='Commonwealth of the Northern Mariana Islands'),
#  Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America'),
#  Country(alpha_2='SV', alpha_3='SLV', name='El Salvador', numeric='222', official_name='Republic of El Salvador'),
#  Country(alpha_2='GP', alpha_3='GLP', name='Guadeloupe', numeric='312'),
#  Country(alpha_2='KY', alpha_3='CYM', name='Cayman Islands', numeric='136'),
#  Country(alpha_2='NU', alpha_3='NIU', name='Niue', numeric='570', official_name='Niue'),
#  Country(alpha_2='IM', alpha_3='IMN', name='Isle of Man', numeric='833'),
#  Country(alpha_2='UM', alpha_3='UMI', name='United States Minor Outlying Islands', numeric='581'),
#  Country(alpha_2='CX', alpha_3='CXR', name='Christmas Island', numeric='162'),
#  Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784'),
#  Country(alpha_2='PS', alpha_3='PSE', name='Palestine, State of', numeric='275', official_name='the State of Palestine'),
#  Country(alpha_2='BN', alpha_3='BRN', name='Brunei Darussalam', numeric='096'),
#  Country(alpha_2='SS', alpha_3='SSD', name='South Sudan', numeric='728', official_name='Republic of South Sudan')]

# %%
'(Vatican City State)'.strip('(').strip(')').split(' ')
# Out:
# ['Vatican', 'City', 'State']

# %%
'Norfolk' in clean_email_words
# Out:
# True

# %%
false_neg_countries = []

for country in pot_false_neg:
    country_words = country.name.strip('(').strip(')').split()
    for word in country_words:
        if word in clean_email_words:
            false_neg_countries.append(country)
            
false_neg_countries = list(set(false_neg_countries))

# %%
print(len(false_neg_countries))
false_neg_countries
# Out:
# 45
# [Country(alpha_2='CV', alpha_3='CPV', name='Cabo Verde', numeric='132', official_name='Republic of Cabo Verde'),
#  Country(alpha_2='CD', alpha_3='COD', name='Congo, The Democratic Republic of the', numeric='180'),
#  Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643'),
#  Country(alpha_2='SL', alpha_3='SLE', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone'),
#  Country(alpha_2='VA', alpha_3='VAT', name='Holy See (Vatican City State)', numeric='336'),
#  Country(alpha_2='IO', alpha_3='IOT', name='British Indian Ocean Territory', numeric='086'),
#  Country(alpha_2='PR', alpha_3='PRI', name='Puerto Rico', numeric='630'),
#  Country(alpha_2='GB', alpha_3='GBR', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland'),
#  Country(alpha_2='HM', alpha_3='HMD', name='Heard Island and McDonald Islands', numeric='334'),
#  Country(alpha_2='NF', alpha_3='NFK', name='Norfolk Island', numeric='574'),
#  Country(alpha_2='HK', alpha_3='HKG', name='Hong Kong', numeric='344', official_name='Hong Kong Special Administrative Region of China'),
#  Country(alpha_2='PM', alpha_3='SPM', name='Saint Pierre and Miquelon', numeric='666'),
#  Country(alpha_2='MD', alpha_3='MDA', common_name='Moldova', name='Moldova, Republic of', numeric='498', official_name='Republic of Moldova'),
#  Country(alpha_2='LC', alpha_3='LCA', name='Saint Lucia', numeric='662'),
#  Country(alpha_2='CI', alpha_3='CIV', name="Côte d'Ivoire", numeric='384', official_name="Republic of Côte d'Ivoire"),
#  Country(alpha_2='PS', alpha_3='PSE', name='Palestine, State of', numeric='275', official_name='the State of Palestine'),
#  Country(alpha_2='VI', alpha_3='VIR', name='Virgin Islands, U.S.', numeric='850', official_name='Virgin Islands of the United States'),
#  Country(alpha_2='CR', alpha_3='CRI', name='Costa Rica', numeric='188', official_name='Republic of Costa Rica'),
#  Country(alpha_2='MF', alpha_3='MAF', name='Saint Martin (French part)', numeric='663'),
#  Country(alpha_2='BA', alpha_3='BIH', name='Bosnia and Herzegovina', numeric='070', official_name='Republic of Bosnia and Herzegovina'),
#  Country(alpha_2='AS', alpha_3='ASM', name='American Samoa', numeric='016'),
#  Country(alpha_2='MK', alpha_3='MKD', name='Macedonia, Republic of', numeric='807', official_name='The Former Yugoslav Republic of Macedonia'),
#  Country(alpha_2='NC', alpha_3='NCL', name='New Caledonia', numeric='540'),
#  Country(alpha_2='VC', alpha_3='VCT', name='Saint Vincent and the Grenadines', numeric='670'),
#  Country(alpha_2='TT', alpha_3='TTO', name='Trinidad and Tobago', numeric='780', official_name='Republic of Trinidad and Tobago'),
#  Country(alpha_2='LA', alpha_3='LAO', name="Lao People's Democratic Republic", numeric='418'),
#  Country(alpha_2='NZ', alpha_3='NZL', name='New Zealand', numeric='554'),
#  Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410'),
#  Country(alpha_2='FO', alpha_3='FRO', name='Faroe Islands', numeric='234'),
#  Country(alpha_2='GF', alpha_3='GUF', name='French Guiana', numeric='254'),
#  Country(alpha_2='DO', alpha_3='DOM', name='Dominican Republic', numeric='214'),
#  Country(alpha_2='FM', alpha_3='FSM', name='Micronesia, Federated States of', numeric='583', official_name='Federated States of Micronesia'),
#  Country(alpha_2='PG', alpha_3='PNG', name='Papua New Guinea', numeric='598', official_name='Independent State of Papua New Guinea'),
#  Country(alpha_2='SM', alpha_3='SMR', name='San Marino', numeric='674', official_name='Republic of San Marino'),
#  Country(alpha_2='MP', alpha_3='MNP', name='Northern Mariana Islands', numeric='580', official_name='Commonwealth of the Northern Mariana Islands'),
#  Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America'),
#  Country(alpha_2='SV', alpha_3='SLV', name='El Salvador', numeric='222', official_name='Republic of El Salvador'),
#  Country(alpha_2='KY', alpha_3='CYM', name='Cayman Islands', numeric='136'),
#  Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784'),
#  Country(alpha_2='IM', alpha_3='IMN', name='Isle of Man', numeric='833'),
#  Country(alpha_2='UM', alpha_3='UMI', name='United States Minor Outlying Islands', numeric='581'),
#  Country(alpha_2='CX', alpha_3='CXR', name='Christmas Island', numeric='162'),
#  Country(alpha_2='CC', alpha_3='CCK', name='Cocos (Keeling) Islands', numeric='166'),
#  Country(alpha_2='BN', alpha_3='BRN', name='Brunei Darussalam', numeric='096'),
#  Country(alpha_2='SS', alpha_3='SSD', name='South Sudan', numeric='728', official_name='Republic of South Sudan')]

# %%
## Time for a manual check, 45 samples in my opinion is ok 
## We see already that the problem arises from alpha_2 codes like LA, CC, CV, IM etc.
## Which are common acronyms
## Dominican Republic is a tricky one as the Dominican could mean the religious group.

# %%
bad_codes = ['HM','KY','LA','VI','VC','CV','LC','SJ','UM','SM','CC','PM','GF','IM','FO','GS','MP','NC','MF', 'IO']

for code in bad_codes:
    country = pycountry.countries.get(alpha_2 = code )
    try:
        false_neg_countries.remove(country)
    except:
        pass

# %%
len(false_neg_countries)
# Out:
# 27

# %%
false_neg_countries
# Out:
# [Country(alpha_2='CD', alpha_3='COD', name='Congo, The Democratic Republic of the', numeric='180'),
#  Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643'),
#  Country(alpha_2='SL', alpha_3='SLE', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone'),
#  Country(alpha_2='VA', alpha_3='VAT', name='Holy See (Vatican City State)', numeric='336'),
#  Country(alpha_2='PR', alpha_3='PRI', name='Puerto Rico', numeric='630'),
#  Country(alpha_2='GB', alpha_3='GBR', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland'),
#  Country(alpha_2='NF', alpha_3='NFK', name='Norfolk Island', numeric='574'),
#  Country(alpha_2='HK', alpha_3='HKG', name='Hong Kong', numeric='344', official_name='Hong Kong Special Administrative Region of China'),
#  Country(alpha_2='MD', alpha_3='MDA', common_name='Moldova', name='Moldova, Republic of', numeric='498', official_name='Republic of Moldova'),
#  Country(alpha_2='CI', alpha_3='CIV', name="Côte d'Ivoire", numeric='384', official_name="Republic of Côte d'Ivoire"),
#  Country(alpha_2='PS', alpha_3='PSE', name='Palestine, State of', numeric='275', official_name='the State of Palestine'),
#  Country(alpha_2='CR', alpha_3='CRI', name='Costa Rica', numeric='188', official_name='Republic of Costa Rica'),
#  Country(alpha_2='BA', alpha_3='BIH', name='Bosnia and Herzegovina', numeric='070', official_name='Republic of Bosnia and Herzegovina'),
#  Country(alpha_2='AS', alpha_3='ASM', name='American Samoa', numeric='016'),
#  Country(alpha_2='MK', alpha_3='MKD', name='Macedonia, Republic of', numeric='807', official_name='The Former Yugoslav Republic of Macedonia'),
#  Country(alpha_2='TT', alpha_3='TTO', name='Trinidad and Tobago', numeric='780', official_name='Republic of Trinidad and Tobago'),
#  Country(alpha_2='NZ', alpha_3='NZL', name='New Zealand', numeric='554'),
#  Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410'),
#  Country(alpha_2='DO', alpha_3='DOM', name='Dominican Republic', numeric='214'),
#  Country(alpha_2='FM', alpha_3='FSM', name='Micronesia, Federated States of', numeric='583', official_name='Federated States of Micronesia'),
#  Country(alpha_2='PG', alpha_3='PNG', name='Papua New Guinea', numeric='598', official_name='Independent State of Papua New Guinea'),
#  Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America'),
#  Country(alpha_2='SV', alpha_3='SLV', name='El Salvador', numeric='222', official_name='Republic of El Salvador'),
#  Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784'),
#  Country(alpha_2='CX', alpha_3='CXR', name='Christmas Island', numeric='162'),
#  Country(alpha_2='BN', alpha_3='BRN', name='Brunei Darussalam', numeric='096'),
#  Country(alpha_2='SS', alpha_3='SSD', name='South Sudan', numeric='728', official_name='Republic of South Sudan')]

# %%
countries_by_name = countries_by_name + false_neg_countries
len(countries_by_name)
# Out:
# 161

# %%
ref_countries = []
ref_countries = ref_countries + list(country.name.split(',')[0] for country in countries_by_name)

# %%
ref_countries
# Out:
# ['Guinea-Bissau',
#  'Hungary',
#  'Algeria',
#  'Luxembourg',
#  'Kyrgyzstan',
#  'Brazil',
#  'Lithuania',
#  'Georgia',
#  'Lesotho',
#  'Haiti',
#  'Andorra',
#  'Canada',
#  'Jamaica',
#  'Bahamas',
#  'Gabon',
#  'Guinea',
#  'Colombia',
#  'Azerbaijan',
#  'Gambia',
#  'Maldives',
#  'Finland',
#  'Belarus',
#  'Japan',
#  'Belgium',
#  'Mexico',
#  'Bulgaria',
#  'Madagascar',
#  'Argentina',
#  'Kazakhstan',
#  'Egypt',
#  'Burundi',
#  'Iceland',
#  'Bermuda',
#  'Libya',
#  'France',
#  'Liberia',
#  'Armenia',
#  'Kenya',
#  'Barbados',
#  'Croatia',
#  'Congo',
#  'Ghana',
#  'Guatemala',
#  'Guyana',
#  'Bahrain',
#  'Guam',
#  'Angola',
#  'Jersey',
#  'Austria',
#  'Cameroon',
#  'Lebanon',
#  'Spain',
#  'Italy',
#  'Antarctica',
#  'Afghanistan',
#  'Cuba',
#  'Cambodia',
#  'Mali',
#  'Morocco',
#  'Israel',
#  'Cyprus',
#  'Estonia',
#  'Monaco',
#  'Ethiopia',
#  'Indonesia',
#  'China',
#  'Botswana',
#  'Bangladesh',
#  'Greece',
#  'Denmark',
#  'Switzerland',
#  'Kuwait',
#  'Chile',
#  'Honduras',
#  'Latvia',
#  'Germany',
#  'Ireland',
#  'Bhutan',
#  'Australia',
#  'Iraq',
#  'Ecuador',
#  'Jordan',
#  'Gibraltar',
#  'India',
#  'Mauritania',
#  'Nicaragua',
#  'Singapore',
#  'Slovenia',
#  'Ukraine',
#  'Pakistan',
#  'Slovakia',
#  'Suriname',
#  'Malawi',
#  'Yemen',
#  'Peru',
#  'Romania',
#  'Sudan',
#  'Uruguay',
#  'Montenegro',
#  'Turkey',
#  'Paraguay',
#  'Chad',
#  'Malta',
#  'Mongolia',
#  'Panama',
#  'Palau',
#  'Nigeria',
#  'Norway',
#  'Samoa',
#  'Uganda',
#  'Niger',
#  'Timor-Leste',
#  'Philippines',
#  'Serbia',
#  'Tunisia',
#  'Mozambique',
#  'Sweden',
#  'Thailand',
#  'Seychelles',
#  'Malaysia',
#  'Oman',
#  'Somalia',
#  'Portugal',
#  'Qatar',
#  'Poland',
#  'Namibia',
#  'Senegal',
#  'Rwanda',
#  'Nepal',
#  'Netherlands',
#  'Zambia',
#  'Myanmar',
#  'Uzbekistan',
#  'Zimbabwe',
#  'Congo',
#  'Russian Federation',
#  'Sierra Leone',
#  'Holy See (Vatican City State)',
#  'Puerto Rico',
#  'United Kingdom',
#  'Norfolk Island',
#  'Hong Kong',
#  'Moldova',
#  "Côte d'Ivoire",
#  'Palestine',
#  'Costa Rica',
#  'Bosnia and Herzegovina',
#  'American Samoa',
#  'Macedonia',
#  'Trinidad and Tobago',
#  'New Zealand',
#  'Korea',
#  'Dominican Republic',
#  'Micronesia',
#  'Papua New Guinea',
#  'United States',
#  'El Salvador',
#  'United Arab Emirates',
#  'Christmas Island',
#  'Brunei Darussalam',
#  'South Sudan']

# %%
ref_lines = {}
for ref_country in ref_countries:
    ref_lines[ref_country] = ''.join(list((line + '\n') for line in email_lines if (ref_country in line)))

# %%
for country in ref_lines.keys():
    ref_lines[country] = re.sub('<.*>', '', ref_lines[country])
    ref_lines[country]  = re.sub('[0-9]*', '', ref_lines[country])
    ref_lines[country] = re.sub('[^\w\s]', '', ref_lines[country])
    ref_lines[country] = ref_lines[country].lower()

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
vader_analyzer = SentimentIntensityAnalyzer()

# %%
ref_sentiments = {}
for country in ref_lines.keys():
    ref_sentiments[country] = vader_analyzer.polarity_scores(ref_lines[country])

# %%
sentiments = pd.DataFrame.from_dict(ref_sentiments, 'index')

# %%
sentiments.head()
# Out:
#                   neg    pos    neu  compound
# Afghanistan     0.108  0.092  0.801   -0.9995
# Algeria         0.058  0.104  0.838    0.7096
# American Samoa  0.000  0.099  0.901    0.5423
# Andorra         0.168  0.000  0.832   -0.8591
# Angola          0.020  0.133  0.847    0.9931

# %%
sentiments.reset_index(inplace = True)

# %%
sentiments.sort('compound', inplace=True)
sentiments['Weight'] = sentiments['index'].apply(lambda x : len(ref_lines[x]))
# Out:
# //anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
minw = min(sentiments.Weight)
maxw = max(sentiments.Weight)
sentiments.Weight = sentiments.Weight.apply(lambda x: x  / (maxw - minw))

# %%
sentiments.set_index('index', inplace=True)

# %%
import seaborn as sb
sb.set_context(rc={"figure.figsize": (45, 15)})
from matplotlib import cm
y = np.array(sentiments['compound'])
colors = cm.RdBu(y / float(max(y)))
plot = plt.scatter(y, y, c=y, cmap = 'RdBu')
plt.clf()
clb = plt.colorbar(plot)
clb.ax.set_title("Polarity")
plt.bar(range(sentiments.shape[0]), sentiments['Weight'], tick_label = sentiments.index, color=colors)
plt.xticks(rotation=90)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## TOPIC MODELLING
# ### It is interesting, given that we seperated the emails by country to tr a topic modelling to see what each country is talking about.
# ### We simply asked for as many topics as there are countries as we saw little improvement to the results.

# %%
import gensim

# %%
from gensim import models, corpora , similarities

# %%
doc = []
for country in ref_lines.keys():
    doc.append(list(set(ref_lines[country].split()) - stopwords))

# %%
dictionary = corpora.Dictionary(doc)
corpus = [dictionary.doc2bow(text) for text in doc]

# %%
lda = models.ldamodel.LdaModel(corpus, id2word = dictionary, num_topics= 152, passes = 5)

# %%
lda.print_topics(152)
# Out:
# [(0,
#  (83,
#   '0.030*"resist" + 0.025*"stem" + 0.019*"qaddafi" + 0.014*"conflicts" + 0.014*"yemen" + 0.013*"met" + 0.013*"timorleste" + 0.013*"militia" + 0.013*"iran" + 0.013*"fled"'),
#  (84,
#   '0.010*"president" + 0.009*"number" + 0.009*"fought" + 0.009*"supported" + 0.009*"brown" + 0.009*"crucial" + 0.009*"save" + 0.009*"seas" + 0.009*"nasheed" + 0.009*"maldives"'),
#  (85,
#   '0.000*"mexico" + 0.000*"republic" + 0.000*"subject" + 0.000*"uruguay" + 0.000*"also" + 0.000*"fw" + 0.000*"issue" + 0.000*"members" + 0.000*"report" + 0.000*"role"'),
#  (86,
#   '0.026*"usaid" + 0.020*"explained" + 0.014*"challenge" + 0.013*"millennium" + 0.013*"provide" + 0.012*"funding" + 0.009*"highly" + 0.008*"departments" + 0.008*"based" + 0.008*"expressing"'),
#  (87,
#   '0.000*"us" + 0.000*"states" + 0.000*"american" + 0.000*"since" + 0.000*"war" + 0.000*"past" + 0.000*"years" + 0.000*"among" + 0.000*"re" + 0.000*"sent"'),
#  (88,
#   '0.018*"netherlands" + 0.013*"hungary" + 0.013*"slovakia" + 0.013*"votes" + 0.012*"italy" + 0.011*"italian" + 0.011*"ukraine" + 0.011*"romania" + 0.011*"germany" + 0.010*"denmark"'),
#  (89,
#   '0.000*"make" + 0.000*"policy" + 0.000*"members" + 0.000*"speech" + 0.000*"subject" + 0.000*"want" + 0.000*"re" + 0.000*"include" + 0.000*"now" + 0.000*"hes"'),
#  (90,
#   '0.004*"clearly" + 0.003*"freedom" + 0.003*"primary" + 0.003*"word" + 0.003*"sent" + 0.003*"construction" + 0.003*"articles" + 0.003*"obamas" + 0.002*"institute" + 0.002*"led"'),
#  (91,
#   '0.000*"called" + 0.000*"news" + 0.000*"statement" + 0.000*"call" + 0.000*"visit" + 0.000*"back" + 0.000*"years" + 0.000*"president" + 0.000*"now" + 0.000*"good"'),
#  (92,
#   '0.012*"egypts" + 0.011*"match" + 0.011*"project" + 0.009*"cup" + 0.009*"outlines" + 0.008*"millions" + 0.008*"discussion" + 0.008*"indicates" + 0.007*"concerned" + 0.007*"simple"'),
#  (93,
#   '0.000*"russian" + 0.000*"meeting" + 0.000*"haiti" + 0.000*"charge" + 0.000*"now" + 0.000*"countries" + 0.000*"france" + 0.000*"nico" + 0.000*"major" + 0.000*"hrc"'),
#  (94,
#   '0.001*"called" + 0.001*"holding" + 0.001*"vauxhall" + 0.001*"whose" + 0.001*"classical" + 0.001*"dmitri" + 0.001*"participated" + 0.001*"jacobson" + 0.001*"jose" + 0.001*"role"'),
#  (95,
#   '0.000*"part" + 0.000*"yet" + 0.000*"fw" + 0.000*"president" + 0.000*"week" + 0.000*"conference" + 0.000*"two" + 0.000*"nothing" + 0.000*"wanted" + 0.000*"west"'),
#  (96,
#   '0.006*"opinion" + 0.006*"southern" + 0.006*"announce" + 0.006*"hillary" + 0.006*"activities" + 0.006*"s" + 0.006*"society" + 0.005*"offices" + 0.005*"reuters" + 0.005*"longer"'),
#  (111,
#   '0.014*"block" + 0.014*"excuse" + 0.014*"casualties" + 0.013*"progress" + 0.011*"fragile" + 0.011*"adding" + 0.010*"collectively" + 0.010*"audiences" + 0.010*"seoul" + 0.009*"college"'),
#  (112,
#   '0.006*"permanent" + 0.006*"amounts" + 0.005*"ceremony" + 0.005*"per" + 0.005*"conversations" + 0.004*"required" + 0.004*"begin" + 0.004*"respond" + 0.004*"palau" + 0.004*"wed"'),
#  (113,
#   '0.000*"said" + 0.000*"re" + 0.000*"well" + 0.000*"new" + 0.000*"government" + 0.000*"much" + 0.000*"take" + 0.000*"set" + 0.000*"will" + 0.000*"toward"'),
#  (114,
#   '0.009*"said" + 0.009*"accord" + 0.008*"londons" + 0.008*"metropolitan" + 0.008*"copenhagen" + 0.008*"leon" + 0.007*"panetta" + 0.005*"missions" + 0.005*"foremost" + 0.005*"disaster"'),
#  (115,
#   '0.022*"jihadists" + 0.022*"anniversary" + 0.013*"poland" + 0.011*"congratulate" + 0.011*"march" + 0.011*"russia" + 0.008*"o" + 0.008*"today" + 0.007*"transit" + 0.007*"finland"'),
#  (116,
#   '0.008*"state" + 0.007*"president" + 0.007*"sustained" + 0.007*"significantly" + 0.007*"interviews" + 0.007*"many" + 0.006*"relationships" + 0.006*"comment" + 0.006*"emerged" + 0.006*"remains"'),
#  (117,
#   '0.014*"spill" + 0.009*"unlike" + 0.009*"close" + 0.009*"turned" + 0.008*"claimed" + 0.008*"zelaya" + 0.008*"important" + 0.008*"short" + 0.008*"run" + 0.007*"ukraine"'),
#  (118,
#   '0.007*"currency" + 0.007*"answer" + 0.007*"sustainable" + 0.006*"abuse" + 0.006*"third" + 0.005*"launch" + 0.005*"scale" + 0.005*"years" + 0.005*"impact" + 0.005*"represent"'),
#  (119,
#   '0.005*"order" + 0.005*"member" + 0.005*"prevent" + 0.005*"heavily" + 0.005*"talk" + 0.005*"bid" + 0.005*"takes" + 0.004*"acting" + 0.004*"pointed" + 0.004*"else"'),
#  (120,
#   '0.000*"state" + 0.000*"will" + 0.000*"people" + 0.000*"border" + 0.000*"us" + 0.000*"fw" + 0.000*"subject" + 0.000*"secretary" + 0.000*"southern" + 0.000*"sudan"'),
#  (121,
#   '0.001*"europe" + 0.000*"france" + 0.000*"president" + 0.000*"belarus" + 0.000*"austria" + 0.000*"whether" + 0.000*"reuters" + 0.000*"armenia" + 0.000*"last" + 0.000*"used"'),
#  (122,
#   '0.013*"attacks" + 0.011*"nothing" + 0.009*"basis" + 0.009*"newsmahogany" + 0.009*"missed" + 0.008*"sanctions" + 0.008*"gulf" + 0.008*"statements" + 0.008*"pursue" + 0.008*"french"'),
#  (123,
#   '0.013*"ii" + 0.010*"makes" + 0.010*"sovereignty" + 0.009*"claim" + 0.009*"expected" + 0.008*"entry" + 0.008*"netanyahu" + 0.008*"participants" + 0.008*"september" + 0.008*"settlements"'),
#  (124,
#   '0.009*"impose" + 0.008*"suspending" + 0.008*"convince" + 0.007*"mitchell" + 0.006*"fair" + 0.006*"painful" + 0.006*"map" + 0.006*"prepares" + 0.006*"institution" + 0.006*"commit"'),
#   '0.000*"soldiers" + 0.000*"peace" + 0.000*"much" + 0.000*"take" + 0.000*"army" + 0.000*"government" + 0.000*"meeting" + 0.000*"change" + 0.000*"people" + 0.000*"strategy"'),
#  (139,
#   '0.000*"states" + 0.000*"government" + 0.000*"way" + 0.000*"policy" + 0.000*"also" + 0.000*"understanding" + 0.000*"united" + 0.000*"elections" + 0.000*"state" + 0.000*"outcome"'),
#  (140,
#   '0.011*"otherwise" + 0.011*"ambassador" + 0.011*"relied" + 0.010*"s" + 0.009*"will" + 0.008*"decided" + 0.008*"stable" + 0.008*"corfu" + 0.008*"growth" + 0.008*"nondemocratic"'),
#  (141,
#   '0.017*"showcase" + 0.009*"reflect" + 0.009*"new" + 0.009*"international" + 0.009*"netherlands" + 0.009*"korea" + 0.009*"approach" + 0.009*"needs" + 0.009*"assistance" + 0.009*"spain"'),
#  (142,
#   '0.011*"travels" + 0.010*"released" + 0.010*"safe" + 0.009*"willing" + 0.009*"tehran" + 0.009*"thanks" + 0.008*"alert" + 0.007*"planned" + 0.007*"ill" + 0.007*"video"'),
#  (143,
#   '0.013*"worlds" + 0.011*"might" + 0.010*"dont" + 0.010*"away" + 0.009*"mr" + 0.009*"lead" + 0.009*"needed" + 0.008*"advantage" + 0.008*"natural" + 0.008*"france"'),
#  (144,
#   '0.008*"speaking" + 0.008*"congress" + 0.007*"couple" + 0.007*"global" + 0.007*"claimed" + 0.007*"agency" + 0.006*"journalists" + 0.006*"forum" + 0.006*"going" + 0.006*"traveling"'),
#  (145,
#   '0.000*"security" + 0.000*"re" + 0.000*"first" + 0.000*"later" + 0.000*"authorities" + 0.000*"obama" + 0.000*"us" + 0.000*"mr" + 0.000*"community" + 0.000*"allies"'),
#  (146,
#   '0.015*"sunday" + 0.014*"paris" + 0.014*"race" + 0.014*"wins" + 0.014*"ecuadorean" + 0.014*"bulgarian" + 0.013*"bokova" + 0.013*"bukova" + 0.013*"ivonne" + 0.013*"irina"'),
#  (147,
#   '0.010*"russians" + 0.009*"defence" + 0.009*"close" + 0.008*"institute" + 0.008*"civilian" + 0.007*"thoughts" + 0.007*"freedom" + 0.007*"democracies" + 0.007*"record" + 0.007*"large"'),
#  (148,
#   '0.000*"members" + 0.000*"state" + 0.000*"re" + 0.000*"afghanistan" + 0.000*"working" + 0.000*"said" + 0.000*"going" + 0.000*"whether" + 0.000*"others" + 0.000*"open"'),
#  (149,
#   '0.007*"barred" + 0.007*"shepherding" + 0.007*"rousing" + 0.007*"haifa" + 0.007*"instrument" + 0.007*"shouldworry" + 0.007*"ascertain" + 0.007*"promises" + 0.007*"alas" + 0.007*"elliott"'),
#  (150,
#   '0.015*"generating" + 0.014*"jobgenerating" + 0.014*"strengthened" + 0.014*"agreements" + 0.012*"robust" + 0.012*"brazils" + 0.011*"export" + 0.011*"barriers" + 0.010*"muscle" + 0.010*"citing"'),
#  (151,
#   '0.009*"massive" + 0.008*"population" + 0.008*"brief" + 0.007*"nearly" + 0.007*"care" + 0.007*"project" + 0.007*"activity" + 0.007*"weeks" + 0.006*"water" + 0.006*"countrys"')]
